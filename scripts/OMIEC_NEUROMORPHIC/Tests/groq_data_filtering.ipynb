# %%
import numpy as np
import pandas as pd
from groq import Groq
import time

# %%
df = pd.read_excel('../../data/raw/OMIEC_NEUROMORPHIC_20_08_24_v2.xlsx')

# %%
df['Abstract']
# Out:
# 0      Organic electrochemical transistors are a prom...
# 1      Organic mixed ionic-electronic conductors (OMI...
# 2      Organic mixed ionic-electronic conductors (OMI...
# 3      The field of organic mixed ionic-electronic co...
# 4      Operational stability underpins the successful...
#                              ...
# 118    In recent years, organic electrochemical trans...
# 119    Organic electrochemical transistors (OECTs) ma...
# 120    Owing to their potential advantages such as lo...
# 121    Due to similar transmission characteristics of...
# 122    Synaptic plasticity functions play a crucial r...
# Name: Abstract, Length: 123, dtype: object

# %%
GROQ_API_KEY = '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'

# %%
# groq
client = Groq(
    api_key=GROQ_API_KEY,
)

# respostas
responses_list = []

# todos os abstracts
total = len(df['Abstract'])
total_time = 0


for index, row in df.iterrows():
    start_time = time.time()

    # tempo
    print('\n', index, 'of', total, 'remaining estimated time', (total-index)*(total_time/(index+1)))

    # chat request
    completion = client.chat.completions.create(
        model="llama3-70b-8192",
        messages=[
            {
                "role": "system",
                "content": "RolePlay as a bot seeking for polymers of the type OMIEC, also known as Organic Mixed Ionic Electronic Conductors."
            },
            {
                "role": "user",
                "content": "For the text I will input next, identify any Organic Mixed Ionic Electronic Conductors (OMIEC) polymers that are used for neuromorphic devices. Provide only polymers that are mentioned in the text and provide only their names, separated by semicolons. If no such polymers are found in the text, the output should be 'None'. Do not repeat any polymer name. Do not output the polymer type. Do not output other types of materials. If the polymer name is written in full, replace it with its abbreviation."

            },
            {
                "role": "assistant",
                "content": "Hello, I will tell the polymers that are used in neuromorphic devices of any text you input next"
            },
            {
                "role": "user",
                "content": f"{row['Abstract']}"  # Use f-string to format the abstract
            }
        ],
        temperature=0.3,
        max_tokens=1024,
        top_p=0.9,
        stream=True,
        stop=None,
    )

    # coletar respostas
    response = ""

    # Stream the completion result and print the content
    for chunk in completion:
        response += chunk.choices[0].delta.content or ""
        print(chunk.choices[0].delta.content or "", end="")

    print()
    
    # listas de respostas
    responses_list.append({ 'index': index, 'response': response })

    # tempo total
    total_time += time.time() - start_time
# Out:
#  0 of 123 remaining estimated time 0.0
# PT; NDI
#
#  1 of 123 remaining estimated time 21.103466749191284
# PEDOT:PSS; Mel
#
#  2 of 123 remaining estimated time 25.860033909479775
# P3MEEET
#
#  3 of 123 remaining estimated time 28.516488075256348
# None
#
#  4 of 123 remaining estimated time 29.861365032196044
# None
#
#  5 of 123 remaining estimated time 30.46850609779358
# None
#
#  6 of 123 remaining estimated time 30.49908910478864
# None
#
#  7 of 123 remaining estimated time 49.2579288482666
# None
#
#  8 of 123 remaining estimated time 90.37875096003214
# None
#
#  9 of 123 remaining estimated time 124.0158266544342
# P-3O; P-4O; P-5O; P-6O
#
#  10 of 123 remaining estimated time 159.57909425822172
# PEDOT:PSS
#
#  11 of 123 remaining estimated time 188.49652163187665
# None
#
#  12 of 123 remaining estimated time 203.87288563068097
# PBBT-Me; PBBT-H; BBL
#
#  13 of 123 remaining estimated time 232.73748738425115
# Ru(bpy)(3)(PF6)(2)
#
#  14 of 123 remaining estimated time 249.4922597726186
# None
#
#  15 of 123 remaining estimated time 263.40898686647415
# oEG-substituted regioregular polythiophene
#
#  16 of 123 remaining estimated time 281.2024954908034
# None
#
#  17 of 123 remaining estimated time 290.756305774053
# TIIP
#
#  18 of 123 remaining estimated time 292.80254865947524
# None
#
#  19 of 123 remaining estimated time 310.4891549110412
# PT
#
#  20 of 123 remaining estimated time 315.98510843231566
# gNR-Bu
#
#  21 of 123 remaining estimated time 325.2451785694469
# None
#
#  22 of 123 remaining estimated time 324.26345054999643
# P3HT
#
#  23 of 123 remaining estimated time 327.3159762223562
# PEDOT:PSS
#
#  24 of 123 remaining estimated time 337.60413090705873
# None
#
#  25 of 123 remaining estimated time 338.92402784640973
# None
#
#  26 of 123 remaining estimated time 336.79968054206284
# P3MEEMT
#
#  27 of 123 remaining estimated time 340.60530689784457
# None
#
#  28 of 123 remaining estimated time 337.8230009407833
# None
#
#  29 of 123 remaining estimated time 337.85205378532413
# None
#
#  30 of 123 remaining estimated time 334.49453258514404
# None
#
#  31 of 123 remaining estimated time 331.18882861733437
# None
#
#  32 of 123 remaining estimated time 330.61138109727335
# None
#
#  33 of 123 remaining estimated time 329.578132909887
# P3T
#
#  34 of 123 remaining estimated time 328.62314340046476
# None
#
#  35 of 123 remaining estimated time 322.3938948313395
# None
#
#  36 of 123 remaining estimated time 324.79196790102367
# MIEC
#
#  37 of 123 remaining estimated time 320.94652593763254
# None
#
#  38 of 123 remaining estimated time 319.35147251838293
# None
#
#  39 of 123 remaining estimated time 315.2151963472366
# None
#
#  40 of 123 remaining estimated time 313.4093856637071
# P3HHT; p(g2T-TT)
#
#  41 of 123 remaining estimated time 311.86932925950913
# PEDOT:PSS;p(g2T-TT)
#
#  42 of 123 remaining estimated time 312.6628882884979
# None
#
#  43 of 123 remaining estimated time 310.32736951654607
# P3HT
#
#  44 of 123 remaining estimated time 307.7983597384559
# PEDOT:PSS
#
#  45 of 123 remaining estimated time 305.22813086924344
# PPY
#
#  46 of 123 remaining estimated time 300.94025649415687
# P3HT
#
#  47 of 123 remaining estimated time 296.68196058273315
# BDOPV-TCNVT; ClBDOPV-TCNVT
#
#  48 of 123 remaining estimated time 295.5946691182195
# None
#
#  49 of 123 remaining estimated time 294.29864241600035
# PEDOT:PSS
#
#  50 of 123 remaining estimated time 289.8970098542232
# p(g2T-T); Homo-gDPP
#
#  51 of 123 remaining estimated time 288.3789068368765
# None
#
#  52 of 123 remaining estimated time 286.52962883913295
# PEDOT:PSS; ETE-COONa
#
#  53 of 123 remaining estimated time 284.7221995724572
# CHIT
#
#  54 of 123 remaining estimated time 278.8131723013791
# None
#
#  55 of 123 remaining estimated time 276.7679621492113
# None
#
#  56 of 123 remaining estimated time 272.2019752870526
# None
#
#  57 of 123 remaining estimated time 268.8023557662964
# p(g2T-T)
#
#  58 of 123 remaining estimated time 266.57209075103367
# None
#
#  59 of 123 remaining estimated time 260.90870310465493
# None
#
#  60 of 123 remaining estimated time 257.6132417233264
# PEDOT:PSS
#
#  61 of 123 remaining estimated time 255.40324378013608
# None
#
#  62 of 123 remaining estimated time 252.8101481445252
# None
#
#  63 of 123 remaining estimated time 247.38346427679062
# P3HT; rr-P3HT
#
#  64 of 123 remaining estimated time 245.5584105051481
# None
#
#  65 of 123 remaining estimated time 240.9698446736191
# None
#
#  66 of 123 remaining estimated time 237.28836904710798
# P3HT
#
#  67 of 123 remaining estimated time 233.57836557837095
# None
#
#  68 of 123 remaining estimated time 229.1051816076472
# PPy
#
#  69 of 123 remaining estimated time 225.35278938838414
# None
#
#  70 of 123 remaining estimated time 221.58358467128917
# None
#
#  71 of 123 remaining estimated time 217.04535643259686
# None
#
#  72 of 123 remaining estimated time 212.53292440388302
# None
#
#  73 of 123 remaining estimated time 208.66787143655725
# CDT-BT
#
#  74 of 123 remaining estimated time 204.83986291567484
# PEDOT:PSS
#
#  75 of 123 remaining estimated time 201.9688425064087
# PEDOT:PSS
#
#  76 of 123 remaining estimated time 198.06850563705743
# None
#
#  77 of 123 remaining estimated time 193.54258407690588
# None
#
#  78 of 123 remaining estimated time 189.03760141964202
# None
#
#  79 of 123 remaining estimated time 184.66988617181778
# None
#
#  80 of 123 remaining estimated time 180.74082540582728
# PEDOT:PSS
#
#  81 of 123 remaining estimated time 176.79921231037233
# PEDOT
#
#  82 of 123 remaining estimated time 173.34244088954236
# PNDI2OD-2Tz; PNDIODTEG-2Tz; PNDI2TEG-2Tz
#
#  83 of 123 remaining estimated time 169.35967479433333
# PEDOT:PSS; PCPDTBT-SO3K
#
#  84 of 123 remaining estimated time 165.33033335629634
# None
#
#  85 of 123 remaining estimated time 160.79935406529626
# PEDOT:PSS
#
#  86 of 123 remaining estimated time 156.33318159498018
# PEDOT:PSS
#
#  87 of 123 remaining estimated time 152.6976544748653
# P(gPzDPP-CT2)
#
#  88 of 123 remaining estimated time 148.2303646575199
# None
#
#  89 of 123 remaining estimated time 143.40070140096876
# None
#
#  90 of 123 remaining estimated time 139.72583461855794
# PEDOT:PSS
#
#  91 of 123 remaining estimated time 134.95003393422002
# DPP-g2T
#
#  92 of 123 remaining estimated time 131.24086610476175
# PEDOT:PSS
#
#  93 of 123 remaining estimated time 126.81843067737334
# None
#
#  94 of 123 remaining estimated time 122.434775656148
# PEDOT:PSS; Nafion
#
#  95 of 123 remaining estimated time 118.05866142114003
# None
#
#  96 of 123 remaining estimated time 113.97692599738997
# None
#
#  97 of 123 remaining estimated time 109.61614313904121
# None
#
#  98 of 123 remaining estimated time 105.49631154898442
# None
#
#  99 of 123 remaining estimated time 101.17503192901611
# None
#
#  100 of 123 remaining estimated time 97.30650800289494
# None
#
#  101 of 123 remaining estimated time 92.95476949916166
# None
#
#  102 of 123 remaining estimated time 88.62301478571105
# BBL
#
#  103 of 123 remaining estimated time 84.49644648111784
# None
#
#  104 of 123 remaining estimated time 80.35983135132564
# None
#
#  105 of 123 remaining estimated time 76.20964550971985
# None
#
#  106 of 123 remaining estimated time 71.72803762025923
# None
#
#  107 of 123 remaining estimated time 67.42967270038746
# CPE-K
#
#  108 of 123 remaining estimated time 63.141635984455775
# None
#
#  109 of 123 remaining estimated time 58.93066108010032
# PEDOT:PSS
#
#  110 of 123 remaining estimated time 54.653405030568436
# PEDOT:PSS; PEDOT:Nafion
#
#  111 of 123 remaining estimated time 50.49932987349374
# P(N,N'-BisGly-NPDIBT)
#
#  112 of 123 remaining estimated time 46.44043107581349
# None
#
#  113 of 123 remaining estimated time 42.08006921567414
# None
#
#  114 of 123 remaining estimated time 37.832238585016
# None
#
#  115 of 123 remaining estimated time 33.73429561483449
# PEDOT:PSS
#
#  116 of 123 remaining estimated time 29.484910816208927
# None
#
#  117 of 123 remaining estimated time 25.245785927368424
# None
#
#  118 of 123 remaining estimated time 21.014153145942366
# None
#
#  119 of 123 remaining estimated time 16.826521261533102
# None
#
#  120 of 123 remaining estimated time 12.60679803998017
# P(VDF-TrFE); P3HT
#
#  121 of 123 remaining estimated time 8.394617819395222
# P3HT
#
#  122 of 123 remaining estimated time 4.201400353656552
# None

# %%
# DataFrame
df_with_responses = pd.DataFrame(responses_list)

# salvar para .csv
df_with_responses.to_excel('../../dataframes/llama3-70B-OMIEC200824_0.3_temp_NEUROMORPHIC_RESPONSES_v2.xlsx', index=False)

# %% [markdown]
# #### Playground

# %%
df_with_responses
# Out:
#      index           response
# 0        0            PT; NDI
# 1        1     PEDOT:PSS; Mel
# 2        2            P3MEEET
# 3        3               None
# 4        4               None
# ..     ...                ...
# 118    118               None
# 119    119               None
# 120    120  P(VDF-TrFE); P3HT
# 121    121               P3HT
# 122    122               None
#
# [123 rows x 2 columns]
