# %%
import numpy as np
import pandas as pd
from groq import Groq
import os
import time

# %%
df = pd.read_excel('../../data/raw/OMIEC_19_08_24.xlsx')

# %%
df['Abstract']
# Out:
# 0       Owing to their outstanding electrical/electroc...
# 1       A synthesis method for large-scale conjugated ...
# 2       Understanding the structural and dynamic prope...
# 3       An essential part of developing organic mixed ...
# 4       n-Type organic electrochemical transistors (OE...
#                               ...
# 1598    Glucocorticoids are being found to influence e...
# 1599    This study was conducted to compare the sensit...
# 1600    The identification of P450 mRNAs in a tissue p...
# 1601    Growth hormone (GH) may directly affect the ex...
# 1602    A comprehensive examination of patients with v...
# Name: Abstract, Length: 1603, dtype: object

# %%
GROQ_API_KEY = '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'

# %%
# groq
client = Groq(
    api_key=GROQ_API_KEY,
)

# respostas
responses_list = []

# todos os abstracts
total = len(df['Abstract'])
total_time = 0


for index, row in df.iterrows():
    start_time = time.time()

    # tempo
    print('\n', index, 'of', total, 'remaining estimated time', (total-index)*(total_time/(index+1)))

    # chat request
    completion = client.chat.completions.create(
        model="llama3-70b-8192",
        messages=[
            {
                "role": "system",
                "content": "RolePlay as a bot seeking for polymers of the type OMIEC, also known as Organic Mixed Ionic Electronic Conductors."
            },
            {
                "role": "user",
                "content": "For the text I will input next, identify any Organic Mixed Ionic Electronic Conductors (OMIEC) polymers mentioned and provide only their names, separated by semicolons. If no such polymers are found in the text, the output should be 'None'. Do not repeat any polymer name. Do not output the polymer type. If the polymer name is written in full, replace it with its abbreviation."
            },
            {
                "role": "assistant",
                "content": "Hello, I will tell you the names of OMIEC-type polymers mentioned in any text you input."
            },
            {
                "role": "user",
                "content": f"{row['Abstract']}"  # Use f-string to format the abstract
            }
        ],
        temperature=0.3,
        max_tokens=1024,
        top_p=0.9,
        stream=True,
        stop=None,
    )

    # coletar respostas
    response = ""

    # Stream the completion result and print the content
    for chunk in completion:
        response += chunk.choices[0].delta.content or ""
        print(chunk.choices[0].delta.content or "", end="")

    print()
    
    # listas de respostas
    responses_list.append({ 'index': index, 'response': response })

    # tempo total
    total_time += time.time() - start_time
# Out:
#  0 of 1603 remaining estimated time 0.0
# None
#
#  1 of 1603 remaining estimated time 344.01907896995544
# None
#
#  2 of 1603 remaining estimated time 375.8261498610179
# None
#
#  3 of 1603 remaining estimated time 499.6095657348633
# None
#
#  4 of 1603 remaining estimated time 484.3367639064789
# None
#
#  5 of 1603 remaining estimated time 488.59359971682227
# PT; ND
#
#  6 of 1603 remaining estimated time 483.71983541761125
# None
#
#  7 of 1603 remaining estimated time 480.93928027153015
# Mel/PEDOT:PSS
#
#  8 of 1603 remaining estimated time 483.6298269695706
# PEDOT:PSS
#
#  9 of 1603 remaining estimated time 481.69928708076475
# PEDOT:PSS
#
#  10 of 1603 remaining estimated time 478.4995604428378
# None
#
#  11 of 1603 remaining estimated time 475.4965475400289
# PProDOT
#
#  12 of 1603 remaining estimated time 474.6436935204726
# PEDOT
#
#  13 of 1603 remaining estimated time 480.1387253829411
# PEDOT:PSS
#
#  14 of 1603 remaining estimated time 481.9041976610819
# P3MEEET
#
#  15 of 1603 remaining estimated time 481.9457845687866
# None
#
#  16 of 1603 remaining estimated time 881.2118408539715
# None
#
#  17 of 1603 remaining estimated time 1142.2238323158688
# None
#
#  18 of 1603 remaining estimated time 1477.4511070627916
# None
#
#  19 of 1603 remaining estimated time 1684.861291694641
# None
#
#  20 of 1603 remaining estimated time 1914.450179031917
# Pg2T-S; Pg2T-SVS; Pg2T-T
#
#  21 of 1603 remaining estimated time 2229.3711959231982
# None
#
#  22 of 1603 remaining estimated time 2373.6132554800615
# P-3O; P-4O; P-5O; P-6O
#
#  23 of 1603 remaining estimated time 2509.1448163986206
# None
#
#  24 of 1603 remaining estimated time 2756.057404546738
# None
#
#  25 of 1603 remaining estimated time 2871.9417635294108
# PEDOT/PSS
#
#  26 of 1603 remaining estimated time 3029.8831034501395
# None
#
#  27 of 1603 remaining estimated time 3230.9676559312006
# PEDOT:PSS
#
#  28 of 1603 remaining estimated time 3254.989799959906
# None
#
#  29 of 1603 remaining estimated time 3435.590987491608
# 2SgPDI; gPDI
#
#  30 of 1603 remaining estimated time 3559.028738275651
# None
#
#  31 of 1603 remaining estimated time 3620.5847555994987
# P3HT
#
#  32 of 1603 remaining estimated time 3773.8635745409765
# None
#
#  33 of 1603 remaining estimated time 3778.6954041088334
# mLPPP
#
#  34 of 1603 remaining estimated time 3872.363475547518
# naphthodithiophene diimide-based polymer;
#
#  35 of 1603 remaining estimated time 3963.706067827013
# PEDOT:PSS
#
#  36 of 1603 remaining estimated time 4047.601211844264
# PEDOT:PSS
#
#  37 of 1603 remaining estimated time 4094.188450173328
# None
#
#  38 of 1603 remaining estimated time 4147.935646986351
# gNDI-Br-2
#
#  39 of 1603 remaining estimated time 4223.6446348905565
# P3MEEET
#
#  40 of 1603 remaining estimated time 4292.220015240879
# None
#
#  41 of 1603 remaining estimated time 4320.193067630132
# None
#
#  42 of 1603 remaining estimated time 4364.571775636008
# None
#
#  43 of 1603 remaining estimated time 4423.236504468051
# PProDOT-Ph
#
#  44 of 1603 remaining estimated time 4445.998039393955
# PBBT-Me; PBBT-H; BBL
#
#  45 of 1603 remaining estimated time 4537.241983880167
# BBL
#
#  46 of 1603 remaining estimated time 4588.2584592636595
# PEDOT:PSS
#
#  47 of 1603 remaining estimated time 4704.07011727492
# P3HT;
#
#  48 of 1603 remaining estimated time 4718.393036224404
# PANI/PSS
#
#  49 of 1603 remaining estimated time 4762.56079539299
# PTBT-P; PTTBT-P
#
#  50 of 1603 remaining estimated time 4804.071430842082
# p(g(7)NC(n)N); p(g(7)NC(10)N); p(g(7)NC(4)N)
#
#  51 of 1603 remaining estimated time 4850.972825857309
# PE2gTT; PE2gT; PT2gTT; PT2gT
#
#  52 of 1603 remaining estimated time 4964.797073310276
# PEO-PEDOT;
#
#  53 of 1603 remaining estimated time 5030.36655165531
# None
#
#  54 of 1603 remaining estimated time 5035.454650167985
# p(g2T-T); Homo-gDPP
#
#  55 of 1603 remaining estimated time 5098.1388030052185
# hPDI[3]-C-11; hPDI[3]-H
#
#  56 of 1603 remaining estimated time 5103.419572382642
# oEG-substituted regioregular polythiophene
#
#  57 of 1603 remaining estimated time 5168.116531339185
# P(NDIMTEG-T)
#
#  58 of 1603 remaining estimated time 5196.773362058704
# MEH-PPV; PEO
#
#  59 of 1603 remaining estimated time 5223.944253730774
# None
#
#  60 of 1603 remaining estimated time 5251.850914595557
# Ru(bpy)(3)(PF6)(2)
#
#  61 of 1603 remaining estimated time 5252.951148471524
# p(NDI-T2 P75);
#
#  62 of 1603 remaining estimated time 5279.09704715865
# TIIP
#
#  63 of 1603 remaining estimated time 5302.972377613187
# None
#
#  64 of 1603 remaining estimated time 5325.732670090749
# None
#
#  65 of 1603 remaining estimated time 5326.533355113232
# None
#
#  66 of 1603 remaining estimated time 5396.663661960345
# None
#
#  67 of 1603 remaining estimated time 5416.824942196117
# None
#
#  68 of 1603 remaining estimated time 5415.241755454436
# None
#
#  69 of 1603 remaining estimated time 5478.42611718859
# None
#
#  70 of 1603 remaining estimated time 5475.039977285223
# PProDOT
#
#  71 of 1603 remaining estimated time 5471.857407371203
# gIDT-BBT
#
#  72 of 1603 remaining estimated time 5489.433279612293
# None
#
#  73 of 1603 remaining estimated time 5526.474415096077
# P3HOTS(-)TMA(+); P3HOTS(-)TMA(+)-co-P3MEEET; P3MEEET
#
#  74 of 1603 remaining estimated time 5543.831541694005
# None
#
#  75 of 1603 remaining estimated time 5560.024046395954
# None
#
#  76 of 1603 remaining estimated time 5554.07603016457
# p(g3T);
#
#  77 of 1603 remaining estimated time 5597.61711583382
# P3HT; PEO
#
#  78 of 1603 remaining estimated time 5631.932051045986
# CPE
#
#  79 of 1603 remaining estimated time 5625.323674142361
# None
#
#  80 of 1603 remaining estimated time 5637.730299881947
# f-BTI2g-TVTCN; f-BTI2g-TVT
#
#  81 of 1603 remaining estimated time 5650.319000348813
# P1; P2; P3
#
#  82 of 1603 remaining estimated time 5717.265546652207
# PEDOT-PBA
#
#  83 of 1603 remaining estimated time 5745.8133345558535
# None
#
#  84 of 1603 remaining estimated time 5778.636379584144
# POT
#
#  85 of 1603 remaining estimated time 5769.940286054168
# None
#
#  86 of 1603 remaining estimated time 5816.062230356809
# PEDOT/PSS
#
#  87 of 1603 remaining estimated time 5825.895154703748
# None
#
#  88 of 1603 remaining estimated time 5937.854832156321
# gNR-Bu
#
#  89 of 1603 remaining estimated time 5929.300351391898
# PEDOT-b-PEG
#
#  90 of 1603 remaining estimated time 5936.229802325532
# pgBTTT; p(g2T-TT)
#
#  91 of 1603 remaining estimated time 5960.218788043313
# None
#
#  92 of 1603 remaining estimated time 5949.706518842328
# None
#
#  93 of 1603 remaining estimated time 5957.0015762461
# PEDOT; EDOTS; EDOTCOOH
#
#  94 of 1603 remaining estimated time 5963.988602798863
# P3HT
#
#  95 of 1603 remaining estimated time 5962.206042389075
# PBFDO
#
#  96 of 1603 remaining estimated time 5984.004658907959
# PEDOT:PSS
#
#  97 of 1603 remaining estimated time 6019.862933008038
# None
#
#  98 of 1603 remaining estimated time 6054.792647747078
# p(N-T)
#
#  99 of 1603 remaining estimated time 6059.558549499512
# PEDOT:PSS; C(2)mpyrFSI; C(2)mpyrTFSI
#
#  100 of 1603 remaining estimated time 6079.344019422437
# PEDOT:PSS
#
#  101 of 1603 remaining estimated time 6114.025994716905
# None
#
#  102 of 1603 remaining estimated time 6072.9249322645865
# None
#
#  103 of 1603 remaining estimated time 6063.18224966526
# PDPP-2EG; PDPP-3EG; PDPP-4EG; PDPP-5EG
#
#  104 of 1603 remaining estimated time 6096.009154356094
# None
#
#  105 of 1603 remaining estimated time 6069.809563897691
# f-BTI2g-TVTF; f-BTI2g-TVTCl; f-BTI2g-TVT
#
#  106 of 1603 remaining estimated time 6087.772222414194
# None
#
#  107 of 1603 remaining estimated time 6096.415406774591
# None
#
#  108 of 1603 remaining estimated time 6071.009626268247
# None
#
#  109 of 1603 remaining estimated time 6073.864854734595
# None
#
#  110 of 1603 remaining estimated time 6063.337299883902
# None
#
#  111 of 1603 remaining estimated time 6065.398088744708
# IDTBT
#
#  112 of 1603 remaining estimated time 6094.4865821821495
# None
#
#  113 of 1603 remaining estimated time 6069.982799166128
# None
#
#  114 of 1603 remaining estimated time 6058.838869579979
# None
#
#  115 of 1603 remaining estimated time 6062.875410737663
# None
#
#  116 of 1603 remaining estimated time 6051.670354215508
# None
#
#  117 of 1603 remaining estimated time 6040.64412026082
# None
#
#  118 of 1603 remaining estimated time 6029.677575486046
# None
#
#  119 of 1603 remaining estimated time 6007.08727555275
# None
#
#  120 of 1603 remaining estimated time 6009.747257262222
# None
#
#  121 of 1603 remaining estimated time 6023.688938645066
# OMIEC
#
#  122 of 1603 remaining estimated time 6025.586032063011
# LCO
#
#  123 of 1603 remaining estimated time 6016.361540671319
# None
#
#  124 of 1603 remaining estimated time 6011.798165061951
# None
#
#  125 of 1603 remaining estimated time 6001.334382318315
# None
#
#  126 of 1603 remaining estimated time 5979.097201399916
# None
#
#  127 of 1603 remaining estimated time 5993.179794900119
# PEO
#
#  128 of 1603 remaining estimated time 5983.306319630424
# None
#
#  129 of 1603 remaining estimated time 5950.127219416545
# PEDOT:PSS; PEDOT/PSS; PEDOT/Nafion; PEDOT/Hyaluronate; PEDOT/Dextran sulfate; PEDOT/Dexamethasone phosphate; PEDOT/tauroursodeoxycholic acid
#
#  130 of 1603 remaining estimated time 5971.690849853836
# None
#
#  131 of 1603 remaining estimated time 5973.444742954139
# PEDOT-PSS
#
#  132 of 1603 remaining estimated time 5975.43681791492
# None
#
#  133 of 1603 remaining estimated time 5966.1686760631965
# None
#
#  134 of 1603 remaining estimated time 5934.71464406296
# MAPI
#
#  135 of 1603 remaining estimated time 5957.945769422195
# None
#
#  136 of 1603 remaining estimated time 5938.505295774363
# None
#
#  137 of 1603 remaining estimated time 5918.4877891264105
# None
#
#  138 of 1603 remaining estimated time 5898.393545570991
# None
#
#  139 of 1603 remaining estimated time 5879.060001223427
# None
#
#  140 of 1603 remaining estimated time 5860.150353384355
# None
#
#  141 of 1603 remaining estimated time 5840.838651569796
# g2T2-gBT6; g2T2-gBT4
#
#  142 of 1603 remaining estimated time 5848.443428072896
# ES-PANI
#
#  143 of 1603 remaining estimated time 5829.503626359834
# None
#
#  144 of 1603 remaining estimated time 5841.360498975885
# None
#
#  145 of 1603 remaining estimated time 5832.70061183629
# None
#
#  146 of 1603 remaining estimated time 5823.875433792063
# None
#
#  147 of 1603 remaining estimated time 5815.121741552611
# None
#
#  148 of 1603 remaining estimated time 5806.946338407145
# None
#
#  149 of 1603 remaining estimated time 5788.95690612475
# None
#
#  150 of 1603 remaining estimated time 5771.254844580265
# None
#
#  151 of 1603 remaining estimated time 5754.103695442802
# None
#
#  152 of 1603 remaining estimated time 5745.890034201878
# None
#
#  153 of 1603 remaining estimated time 5728.424318889519
# None
#
#  154 of 1603 remaining estimated time 5720.447844240743
# None
#
#  155 of 1603 remaining estimated time 5703.908796567183
# None
#
#  156 of 1603 remaining estimated time 5715.543609398946
# None
#
#  157 of 1603 remaining estimated time 5698.750106407117
# None
#
#  158 of 1603 remaining estimated time 5681.8424722533555
# None
#
#  159 of 1603 remaining estimated time 5683.457798933982
# None
#
#  160 of 1603 remaining estimated time 5675.813413066154
# None
#
#  161 of 1603 remaining estimated time 5677.238805223395
# None
#
#  162 of 1603 remaining estimated time 5669.737704948414
# PEO
#
#  163 of 1603 remaining estimated time 5662.894320139071
# None
#
#  164 of 1603 remaining estimated time 5655.426480141553
# None
#
#  165 of 1603 remaining estimated time 5648.771917782635
# f-BTI2g-SVSCN; f-BSeI2g-SVSCN
#
#  166 of 1603 remaining estimated time 5659.744222306919
# None
#
#  167 of 1603 remaining estimated time 5643.790492154303
# None
#
#  168 of 1603 remaining estimated time 5636.584416127064
# None
#
#  169 of 1603 remaining estimated time 5621.112873820697
# None
#
#  170 of 1603 remaining estimated time 5624.401498735997
# None
#
#  171 of 1603 remaining estimated time 5617.490050249321
# None
#
#  172 of 1603 remaining estimated time 5610.701973868243
# None
#
#  173 of 1603 remaining estimated time 5605.740352416861
# None
#
#  174 of 1603 remaining estimated time 5590.401329863412
# None
#
#  175 of 1603 remaining estimated time 5575.210312924602
# None
#
#  176 of 1603 remaining estimated time 5580.424113749111
# None
#
#  177 of 1603 remaining estimated time 5573.587354828802
# None
#
#  178 of 1603 remaining estimated time 5566.617509672761
# None
#
#  179 of 1603 remaining estimated time 5551.670717175802
# None
#
#  180 of 1603 remaining estimated time 5544.82090597785
# None
#
#  181 of 1603 remaining estimated time 5530.277047288287
# None
#
#  182 of 1603 remaining estimated time 5523.418679056272
# None
#
#  183 of 1603 remaining estimated time 5517.3368385304575
# None
#
#  184 of 1603 remaining estimated time 5511.1039489088835
# None
#
#  185 of 1603 remaining estimated time 5516.301580134258
# None
#
#  186 of 1603 remaining estimated time 5509.973842548176
# None
#
#  187 of 1603 remaining estimated time 5510.969186965455
# None
#
#  188 of 1603 remaining estimated time 5505.05583716448
# None
#
#  189 of 1603 remaining estimated time 5498.615677986647
# None
#
#  190 of 1603 remaining estimated time 5500.3014403488
# PPP-OR11
#
#  191 of 1603 remaining estimated time 5494.93873060743
# None
#
#  192 of 1603 remaining estimated time 5473.8373097360445
# None
#
#  193 of 1603 remaining estimated time 5474.730758605544
# PEDOT:PSS
#
#  194 of 1603 remaining estimated time 5462.735452198371
# None
#
#  195 of 1603 remaining estimated time 5463.461250772281
# None
#
#  196 of 1603 remaining estimated time 5450.005999251671
# None
#
#  197 of 1603 remaining estimated time 5458.805455301747
# None
#
#  198 of 1603 remaining estimated time 5452.500516727342
# None
#
#  199 of 1603 remaining estimated time 5446.470207810402
# None
#
#  200 of 1603 remaining estimated time 5433.410193201322
# None
#
#  201 of 1603 remaining estimated time 5434.098184661109
# None
#
#  202 of 1603 remaining estimated time 5434.571510208064
# None
#
#  203 of 1603 remaining estimated time 5428.68592855977
# None
#
#  204 of 1603 remaining estimated time 5422.406947053351
# None
#
#  205 of 1603 remaining estimated time 5422.945079104415
# None
#
#  206 of 1603 remaining estimated time 5416.550947108706
# None
#
#  207 of 1603 remaining estimated time 5397.013495669915
# None
#
#  208 of 1603 remaining estimated time 5397.710674698843
# None
#
#  209 of 1603 remaining estimated time 5398.215919955572
# None
#
#  210 of 1603 remaining estimated time 5392.153774878425
# P(gTDPP2FT);
#
#  211 of 1603 remaining estimated time 5386.599227941261
# None
#
#  212 of 1603 remaining estimated time 5394.034997989314
# None
#
#  213 of 1603 remaining estimated time 5374.8952443131775
# None
#
#  214 of 1603 remaining estimated time 5369.181281997991
# PEDOT:LIG;
#
#  215 of 1603 remaining estimated time 5370.094532887141
# None
#
#  216 of 1603 remaining estimated time 5364.244338662943
# None
#
#  217 of 1603 remaining estimated time 5358.264741188889
# None
#
#  218 of 1603 remaining estimated time 5358.5154164545065
# None
#
#  219 of 1603 remaining estimated time 5355.749903297424
# PEO
#
#  220 of 1603 remaining estimated time 5337.255422477809
# None
#
#  221 of 1603 remaining estimated time 5332.36158605524
# None
#
#  222 of 1603 remaining estimated time 5326.6043492047775
# None
#
#  223 of 1603 remaining estimated time 5314.97014939785
# PEDOT;
#
#  224 of 1603 remaining estimated time 5303.846097082562
# None
#
#  225 of 1603 remaining estimated time 5304.507287158375
# None
#
#  226 of 1603 remaining estimated time 5293.260563863007
# None
#
#  227 of 1603 remaining estimated time 5293.678679917988
# None
#
#  228 of 1603 remaining estimated time 5294.169362455476
# None
#
#  229 of 1603 remaining estimated time 5294.500852962163
# None
#
#  230 of 1603 remaining estimated time 5282.990740107251
# None
#
#  231 of 1603 remaining estimated time 5271.437166530511
# None
#
#  232 of 1603 remaining estimated time 5259.792751243697
# None
#
#  233 of 1603 remaining estimated time 5260.526063075432
# None
#
#  234 of 1603 remaining estimated time 5255.216156608501
# None
#
#  235 of 1603 remaining estimated time 5249.417991169429
# None
#
#  236 of 1603 remaining estimated time 5232.670995055371
# None
#
#  237 of 1603 remaining estimated time 5224.299922087614
# P3HT
#
#  238 of 1603 remaining estimated time 5230.554973610275
# None
#
#  239 of 1603 remaining estimated time 5230.9617498437565
# None
#
#  240 of 1603 remaining estimated time 5219.737034272356
# None
#
#  241 of 1603 remaining estimated time 5225.7012843533985
# None
#
#  242 of 1603 remaining estimated time 5214.689048283385
# None
#
#  243 of 1603 remaining estimated time 5203.602342605591
# None
#
#  244 of 1603 remaining estimated time 5192.550391195258
# None
#
#  245 of 1603 remaining estimated time 5198.382760931806
# LixV2O5
#
#  246 of 1603 remaining estimated time 5193.191085823151
# None
#
#  247 of 1603 remaining estimated time 5187.869951478897
# None
#
#  248 of 1603 remaining estimated time 5182.497526244466
# CH3NH3PbI3
#
#  249 of 1603 remaining estimated time 5182.50903912735
# None
#
#  250 of 1603 remaining estimated time 5182.952823500234
# None
#
#  251 of 1603 remaining estimated time 5177.53144906816
# None
#
#  252 of 1603 remaining estimated time 5167.281549197412
# None
#
#  253 of 1603 remaining estimated time 5161.724028859551
# None
#
#  254 of 1603 remaining estimated time 5151.029126861048
# None
#
#  255 of 1603 remaining estimated time 5156.331380955875
# alpha'-Ag2+deltaTe
#
#  256 of 1603 remaining estimated time 5145.769659663916
# None
#
#  257 of 1603 remaining estimated time 5130.045972833338
# None
#
#  258 of 1603 remaining estimated time 5140.258825290157
# None
#
#  259 of 1603 remaining estimated time 5161.188634256217
# None
#
#  260 of 1603 remaining estimated time 5145.658880591849
# PEDOT:PSS
#
#  261 of 1603 remaining estimated time 5135.654200977951
# None
#
#  262 of 1603 remaining estimated time 5131.388121506107
# None
#
#  263 of 1603 remaining estimated time 5125.97939536427
# None
#
#  264 of 1603 remaining estimated time 5115.608788175403
# None
#
#  265 of 1603 remaining estimated time 5105.4995422345355
# None
#
#  266 of 1603 remaining estimated time 5100.486129520538
# PEO
#
#  267 of 1603 remaining estimated time 5090.094888139127
# None
#
#  268 of 1603 remaining estimated time 5084.997833958346
# None
#
#  269 of 1603 remaining estimated time 5079.966521464454
# None
#
#  270 of 1603 remaining estimated time 5079.738576813378
# None
#
#  271 of 1603 remaining estimated time 5079.792987122255
# None
#
#  272 of 1603 remaining estimated time 5075.107236370499
# None
#
#  273 of 1603 remaining estimated time 5065.149870484414
# PEDOT:PSS
#
#  274 of 1603 remaining estimated time 5069.8119301336465
# None
#
#  275 of 1603 remaining estimated time 5069.347000978995
# PEDOT:PSS
#
#  276 of 1603 remaining estimated time 5064.207170464932
# None
#
#  277 of 1603 remaining estimated time 5056.712068972828
# None
#
#  278 of 1603 remaining estimated time 5056.544789105761
# PEO
#
#  279 of 1603 remaining estimated time 5046.575932560648
# None
#
#  280 of 1603 remaining estimated time 5041.567390252687
# None
#
#  281 of 1603 remaining estimated time 5036.599427042278
# None
#
#  282 of 1603 remaining estimated time 5027.192692575522
# None
#
#  283 of 1603 remaining estimated time 5021.997307253556
# None
#
#  284 of 1603 remaining estimated time 5012.414226381402
# None
#
#  285 of 1603 remaining estimated time 5007.580308298964
# None
#
#  286 of 1603 remaining estimated time 5002.880015520268
#
#
#  287 of 1603 remaining estimated time 4993.0117398997145
# None
#
#  288 of 1603 remaining estimated time 4979.351519630854
# None
#
#  289 of 1603 remaining estimated time 4978.88017302546
# PEDOT:PSS
#
#  290 of 1603 remaining estimated time 4983.432137777715
# PANI
#
#  291 of 1603 remaining estimated time 4983.336420268229
# None
#
#  292 of 1603 remaining estimated time 4978.409267710338
# None
#
#  293 of 1603 remaining estimated time 4969.484316005188
# None
#
#  294 of 1603 remaining estimated time 4960.0305537522845
# None
#
#  295 of 1603 remaining estimated time 4955.07773886178
# None
#
#  296 of 1603 remaining estimated time 4950.770669802271
# None
#
#  297 of 1603 remaining estimated time 4941.601575656226
# LixTiO2
#
#  298 of 1603 remaining estimated time 4939.216399942354
# None
#
#  299 of 1603 remaining estimated time 4938.9294710413615
# None
#
#  300 of 1603 remaining estimated time 4938.4997233599925
# None
#
#  301 of 1603 remaining estimated time 4938.129394385988
# None
#
#  302 of 1603 remaining estimated time 4937.935754231494
# None
#
#  303 of 1603 remaining estimated time 4941.525239458209
# None
#
#  304 of 1603 remaining estimated time 4936.639227718603
# None
#
#  305 of 1603 remaining estimated time 4927.851240857754
# None
#
#  306 of 1603 remaining estimated time 4927.222621566698
# None
#
#  307 of 1603 remaining estimated time 4926.569338067786
# None
#
#  308 of 1603 remaining estimated time 4926.142794333615
# None
#
#  309 of 1603 remaining estimated time 4921.558672763455
# P3HHT;p(g2T-TT)
#
#  310 of 1603 remaining estimated time 4925.324239060809
# None
#
#  311 of 1603 remaining estimated time 4924.579927135736
# PEDOT:PSS
#
#  312 of 1603 remaining estimated time 4920.3984569360655
# None
#
#  313 of 1603 remaining estimated time 4915.443017338492
# None
#
#  314 of 1603 remaining estimated time 4920.878319515501
# None
#
#  315 of 1603 remaining estimated time 4907.988494384138
# None
#
#  316 of 1603 remaining estimated time 4907.17920655031
# None
#
#  317 of 1603 remaining estimated time 4898.343211475409
# None
#
#  318 of 1603 remaining estimated time 4898.421570724081
# None
#
#  319 of 1603 remaining estimated time 4889.394773831963
# None
#
#  320 of 1603 remaining estimated time 4884.419535325695
# None
#
#  321 of 1603 remaining estimated time 4879.699894626689
# None
#
#  322 of 1603 remaining estimated time 4874.680062275553
# None
#
#  323 of 1603 remaining estimated time 4869.870746753833
# None
#
#  324 of 1603 remaining estimated time 4865.024988235326
# None
#
#  325 of 1603 remaining estimated time 4853.109420390217
# None
#
#  326 of 1603 remaining estimated time 4848.287046272821
# None
#
#  327 of 1603 remaining estimated time 4851.298105361985
# None
#
#  328 of 1603 remaining estimated time 4850.751362328834
# None
#
#  329 of 1603 remaining estimated time 4850.261197264989
# None
#
#  330 of 1603 remaining estimated time 4849.741950957797
# None
#
#  331 of 1603 remaining estimated time 4848.7738438341985
# None
#
#  332 of 1603 remaining estimated time 4847.947682574704
# None
#
#  333 of 1603 remaining estimated time 4850.89351893899
# None
#
#  334 of 1603 remaining estimated time 4853.486336728708
# None
#
#  335 of 1603 remaining estimated time 4852.268716281368
# None
#
#  336 of 1603 remaining estimated time 4847.349758395101
# None
#
#  337 of 1603 remaining estimated time 4842.466994546575
# None
#
#  338 of 1603 remaining estimated time 4837.5030300997
# None
#
#  339 of 1603 remaining estimated time 4832.585654595319
# None
#
#  340 of 1603 remaining estimated time 4827.602667398816
# None
#
#  341 of 1603 remaining estimated time 4822.681198015548
# None
#
#  342 of 1603 remaining estimated time 4817.918759193782
# None
#
#  343 of 1603 remaining estimated time 4816.964727210444
# PPP
#
#  344 of 1603 remaining estimated time 4812.165296258097
# None
#
#  345 of 1603 remaining estimated time 4807.318012814991
# None
#
#  346 of 1603 remaining estimated time 4798.767878495994
# PPP-R10; OEO
#
#  347 of 1603 remaining estimated time 4794.597231716945
# None
#
#  348 of 1603 remaining estimated time 4789.760962331876
# None
#
#  349 of 1603 remaining estimated time 4784.907624320984
# None
#
#  350 of 1603 remaining estimated time 4780.057952437306
# PEDOT:PSS
#
#  351 of 1603 remaining estimated time 4771.606869949535
# None
#
#  352 of 1603 remaining estimated time 4766.749336256184
# None
#
#  353 of 1603 remaining estimated time 4758.431077171854
# None
#
#  354 of 1603 remaining estimated time 4757.478864571074
# None
#
#  355 of 1603 remaining estimated time 4752.998725826821
# None
#
#  356 of 1603 remaining estimated time 4748.219373992178
# None
#
#  357 of 1603 remaining estimated time 4743.769558989136
# None
#
#  358 of 1603 remaining estimated time 4738.954489081682
# None
#
#  359 of 1603 remaining estimated time 4734.433310484886
# P3HT
#
#  360 of 1603 remaining estimated time 4736.632388165784
# PF-OECT
#
#  361 of 1603 remaining estimated time 4731.9533208562525
# PEDOT:PSS
#
#  362 of 1603 remaining estimated time 4730.629869953003
# P(C,C); P(O,O); P(C,O)
#
#  363 of 1603 remaining estimated time 4732.892867025438
# PEDOT:PSS
#
#  364 of 1603 remaining estimated time 4721.575081267422
# None
#
#  365 of 1603 remaining estimated time 4720.272334290333
# P3CP
#
#  366 of 1603 remaining estimated time 4715.856298452502
# PEDOT:PSS
#
#  367 of 1603 remaining estimated time 4707.774211391158
# None
#
#  368 of 1603 remaining estimated time 4706.3714360060085
# PEDOT
#
#  369 of 1603 remaining estimated time 4701.649126872501
# PEDOT-TOS;
#
#  370 of 1603 remaining estimated time 4703.867148939169
# None
#
#  371 of 1603 remaining estimated time 4699.227906698821
# None
#
#  372 of 1603 remaining estimated time 4697.882649552087
# P3DDT-s-P3(EG(3))T; P3DDS-s-P3(EG(3))T; P3(EG(3))T
#
#  373 of 1603 remaining estimated time 4697.293335008111
# LSCF6428
#
#  374 of 1603 remaining estimated time 4699.117560555776
# None
#
#  375 of 1603 remaining estimated time 4700.99431840156
# None
#
#  376 of 1603 remaining estimated time 4699.718030507116
# P3MEEMT
#
#  377 of 1603 remaining estimated time 4701.783456121172
# P3HHT
#
#  378 of 1603 remaining estimated time 4693.916655420314
# PEDOT-PSS
#
#  379 of 1603 remaining estimated time 4699.3104488121835
# None
#
#  380 of 1603 remaining estimated time 4692.957627708831
# None
#
#  381 of 1603 remaining estimated time 4681.719490645443
# None
#
#  382 of 1603 remaining estimated time 4680.295191710674
# None
#
#  383 of 1603 remaining estimated time 4675.660393536091
# None
#
#  384 of 1603 remaining estimated time 4670.963421051223
# None
#
#  385 of 1603 remaining estimated time 4669.364919970073
# MIEC
#
#  386 of 1603 remaining estimated time 4664.672559743088
# None
#
#  387 of 1603 remaining estimated time 4660.030130799283
# None
#
#  388 of 1603 remaining estimated time 4655.393900742567
# None
#
#  389 of 1603 remaining estimated time 4650.632288888784
# None
#
#  390 of 1603 remaining estimated time 4649.385372910658
# None
#
#  391 of 1603 remaining estimated time 4644.568597598952
# None
#
#  392 of 1603 remaining estimated time 4639.712018671837
# PEDOT
#
#  393 of 1603 remaining estimated time 4638.250270948797
# None
#
#  394 of 1603 remaining estimated time 4633.5224189812625
# None
#
#  395 of 1603 remaining estimated time 4631.924981526654
# PEDOT
#
#  396 of 1603 remaining estimated time 4630.1324866628765
# None
#
#  397 of 1603 remaining estimated time 4628.501247667188
# PEDOT:PSS
#
#  398 of 1603 remaining estimated time 4620.743566518439
# None
#
#  399 of 1603 remaining estimated time 4616.217814252376
# PEDOT:PSS
#
#  400 of 1603 remaining estimated time 4611.429159879684
# None
#
#  401 of 1603 remaining estimated time 4609.86139088958
# None
#
#  402 of 1603 remaining estimated time 4605.051792411
# None
#
#  403 of 1603 remaining estimated time 4600.284469481742
# PPy
#
#  404 of 1603 remaining estimated time 4597.149924761572
# None
#
#  405 of 1603 remaining estimated time 4592.742607646388
# None
#
#  406 of 1603 remaining estimated time 4588.02318861092
# None
#
#  407 of 1603 remaining estimated time 4583.354472819497
# PEDOT:PSS
#
#  408 of 1603 remaining estimated time 4578.639341339213
# PEDOT:PSS
#
#  409 of 1603 remaining estimated time 4576.8707023073985
# None
#
#  410 of 1603 remaining estimated time 4572.14153352503
# None
#
#  411 of 1603 remaining estimated time 4567.432433813521
# None
#
#  412 of 1603 remaining estimated time 4565.544748477728
# None
#
#  413 of 1603 remaining estimated time 4568.117158240167
# Melanin
#
#  414 of 1603 remaining estimated time 4554.048537011893
# None
#
#  415 of 1603 remaining estimated time 4549.404306416328
# PEDOT:PSS
#
#  416 of 1603 remaining estimated time 4544.8764135671745
# None
#
#  417 of 1603 remaining estimated time 4537.46046993721
# None
#
#  418 of 1603 remaining estimated time 4530.008752314743
# PANI
#
#  419 of 1603 remaining estimated time 4528.187154297601
# None
#
#  420 of 1603 remaining estimated time 4526.320812865844
# None
#
#  421 of 1603 remaining estimated time 4521.825017174273
# None
#
#  422 of 1603 remaining estimated time 4517.277443296803
# None
#
#  423 of 1603 remaining estimated time 4512.668876423026
# None
#
#  424 of 1603 remaining estimated time 4510.992070011251
# iOECTs
#
#  425 of 1603 remaining estimated time 4509.148105554178
# None
#
#  426 of 1603 remaining estimated time 4507.25330589415
# None
#
#  427 of 1603 remaining estimated time 4508.059675354823
# PEDOT: PSS
#
#  428 of 1603 remaining estimated time 4498.002954115679
# PEDOT:PSS
#
#  429 of 1603 remaining estimated time 4496.119020772535
# None
#
#  430 of 1603 remaining estimated time 4499.793695951559
# None
#
#  431 of 1603 remaining estimated time 4500.607669795001
# None
#
#  432 of 1603 remaining estimated time 4496.145333470704
# None
#
#  433 of 1603 remaining estimated time 4488.812189673498
# PEDOT:PSS
#
#  434 of 1603 remaining estimated time 4486.9326214456005
# PPy
#
#  435 of 1603 remaining estimated time 4482.2627364954815
# PEDOT:PSS
#
#  436 of 1603 remaining estimated time 4477.828744265798
# None
#
#  437 of 1603 remaining estimated time 4470.47412654254
# None
#
#  438 of 1603 remaining estimated time 4471.136358631499
# d-gdiPDI; t-gdiPDI
#
#  439 of 1603 remaining estimated time 4469.401415894248
# None
#
#  440 of 1603 remaining estimated time 4464.823137008144
# None
#
#  441 of 1603 remaining estimated time 4462.975489303537
# None
#
#  442 of 1603 remaining estimated time 4461.121135382297
# None
#
#  443 of 1603 remaining estimated time 4456.744397073178
# None
#
#  444 of 1603 remaining estimated time 4452.346347365755
# None
#
#  445 of 1603 remaining estimated time 4450.406505785715
# None
#
#  446 of 1603 remaining estimated time 4445.825257362669
# None
#
#  447 of 1603 remaining estimated time 4441.142678522638
# None
#
#  448 of 1603 remaining estimated time 4439.206003279887
# None
#
#  449 of 1603 remaining estimated time 4437.681324153476
# None
#
#  450 of 1603 remaining estimated time 4433.064321476711
# None
#
#  451 of 1603 remaining estimated time 4428.500732286841
# None
#
#  452 of 1603 remaining estimated time 4426.396814846835
# BSCF
#
#  453 of 1603 remaining estimated time 4419.39904183018
# None
#
#  454 of 1603 remaining estimated time 4419.809545052706
# None
#
#  455 of 1603 remaining estimated time 4415.124023186533
# PEDOT:PSS
#
#  456 of 1603 remaining estimated time 4410.532515600422
# None
#
#  457 of 1603 remaining estimated time 4405.932323218432
# PEDOT: PSS
#
#  458 of 1603 remaining estimated time 4401.262551340922
# None
#
#  459 of 1603 remaining estimated time 4396.685038110484
# None
#
#  460 of 1603 remaining estimated time 4392.230476474555
# None
#
#  461 of 1603 remaining estimated time 4390.188810389795
# None
#
#  462 of 1603 remaining estimated time 4385.709441447104
# None
#
#  463 of 1603 remaining estimated time 4384.7626898103745
# None
#
#  464 of 1603 remaining estimated time 4377.7101577522935
# None
#
#  465 of 1603 remaining estimated time 4376.134378334995
# CPE-K
#
#  466 of 1603 remaining estimated time 4369.158150855173
# PEDOT:PSS
#
#  467 of 1603 remaining estimated time 4367.1502246530645
# None
#
#  468 of 1603 remaining estimated time 4362.5975131175155
# None
#
#  469 of 1603 remaining estimated time 4355.737138969341
# None
#
#  470 of 1603 remaining estimated time 4351.800923320138
# None
#
#  471 of 1603 remaining estimated time 4347.226895964752
# PEDOT;
#
#  472 of 1603 remaining estimated time 4345.139677908153
# None
#
#  473 of 1603 remaining estimated time 4348.311160606674
# None
#
#  474 of 1603 remaining estimated time 4341.4660155793235
# PEDOT:PSS
#
#  475 of 1603 remaining estimated time 4339.2299898051415
# None
#
#  476 of 1603 remaining estimated time 4337.073322160189
# None
#
#  477 of 1603 remaining estimated time 4334.842223339001
# None
#
#  478 of 1603 remaining estimated time 4332.681921864851
# None
#
#  479 of 1603 remaining estimated time 4323.3698583364485
# PEDOTS
#
#  480 of 1603 remaining estimated time 4318.894266709469
# PEDOT:PSS
#
#  481 of 1603 remaining estimated time 4312.010473180114
# None
#
#  482 of 1603 remaining estimated time 4312.110475422186
# POTEDPP;
#
#  483 of 1603 remaining estimated time 4309.98080174785
# None
#
#  484 of 1603 remaining estimated time 4305.503203895411
# None
#
#  485 of 1603 remaining estimated time 4298.6031857802545
# PEDOT:PSS; PSSNa
#
#  486 of 1603 remaining estimated time 4294.116107390402
# PgBT(F)2gT; PgBT(F)2gTT
#
#  487 of 1603 remaining estimated time 4287.428242798712
# None
#
#  488 of 1603 remaining estimated time 4287.5020822766855
# None
#
#  489 of 1603 remaining estimated time 4285.278910328418
# None
#
#  490 of 1603 remaining estimated time 4283.07597305527
# PEDOT:PSS
#
#  491 of 1603 remaining estimated time 4276.335835003271
# None
#
#  492 of 1603 remaining estimated time 4269.611839969067
# None
#
#  493 of 1603 remaining estimated time 4267.383247083016
# PEDOT:PSS
#
#  494 of 1603 remaining estimated time 4265.239112670975
# None
#
#  495 of 1603 remaining estimated time 4260.784112359247
# None
#
#  496 of 1603 remaining estimated time 4258.475933958587
# None
#
#  497 of 1603 remaining estimated time 4256.192690964205
# None
#
#  498 of 1603 remaining estimated time 4251.806455821934
# None
#
#  499 of 1603 remaining estimated time 4251.83594405365
# None
#
#  500 of 1603 remaining estimated time 4247.32370839671
# None
#
#  501 of 1603 remaining estimated time 4242.817293455876
# None
#
#  502 of 1603 remaining estimated time 4240.516229385884
# None
#
#  503 of 1603 remaining estimated time 4238.299209447135
# PEDOT:PSS
#
#  504 of 1603 remaining estimated time 4235.951418066497
# None
#
#  505 of 1603 remaining estimated time 4231.453898143392
# None
#
#  506 of 1603 remaining estimated time 4229.284167748701
# PEDOT:PSS
#
#  507 of 1603 remaining estimated time 4224.745954096787
# AP
#
#  508 of 1603 remaining estimated time 4220.249836758687
# None
#
#  509 of 1603 remaining estimated time 4211.4748871130105
# PEDOT:PSS
#
#  510 of 1603 remaining estimated time 4211.187413427461
# None
#
#  511 of 1603 remaining estimated time 4206.7155275736
# None
#
#  512 of 1603 remaining estimated time 4202.290864014486
# None
#
#  513 of 1603 remaining estimated time 4200.099117918237
# None
#
#  514 of 1603 remaining estimated time 4195.820294395465
# None
#
#  515 of 1603 remaining estimated time 4189.310968384262
# None
#
#  516 of 1603 remaining estimated time 4186.868739885795
# None
#
#  517 of 1603 remaining estimated time 4186.672221192983
# None
#
#  518 of 1603 remaining estimated time 4186.410876501043
# None
#
#  519 of 1603 remaining estimated time 4181.861086586806
# PPy
#
#  520 of 1603 remaining estimated time 4179.466205162645
# PEDOT:PSS
#
#  521 of 1603 remaining estimated time 4177.101757592168
# PEDOT:PSS
#
#  522 of 1603 remaining estimated time 4176.969482289218
# None
#
#  523 of 1603 remaining estimated time 4172.421353391109
# None
#
#  524 of 1603 remaining estimated time 4167.942534224192
# None
#
#  525 of 1603 remaining estimated time 4169.67970391462
# PEDOT:PSS:PVS
#
#  526 of 1603 remaining estimated time 4165.193137309583
# None
#
#  527 of 1603 remaining estimated time 4167.0027090545855
# PEDOT:PSS; Nafion
#
#  528 of 1603 remaining estimated time 4162.56710198516
# None
#
#  529 of 1603 remaining estimated time 4160.086689851869
# PEDOT:PSS
#
#  530 of 1603 remaining estimated time 4157.66389147261
# PEDOT:PSS
#
#  531 of 1603 remaining estimated time 4157.313450232484
# PEDOT:PSS
#
#  532 of 1603 remaining estimated time 4150.72191963992
# None
#
#  533 of 1603 remaining estimated time 4146.2181105595855
# None
#
#  534 of 1603 remaining estimated time 4141.867744506854
# PEDOT:PSS
#
#  535 of 1603 remaining estimated time 4137.316597479493
# None
#
#  536 of 1603 remaining estimated time 4134.812849766716
# None
#
#  537 of 1603 remaining estimated time 4132.4668948003355
# None
#
#  538 of 1603 remaining estimated time 4127.9626013993775
# None
#
#  539 of 1603 remaining estimated time 4125.455024270658
# None
#
#  540 of 1603 remaining estimated time 4122.929699059996
# PEDOT; PEDOT-PSS
#
#  541 of 1603 remaining estimated time 4120.546860742393
# None
#
#  542 of 1603 remaining estimated time 4118.073598390565
# None
#
#  543 of 1603 remaining estimated time 4113.556149812306
# None
#
#  544 of 1603 remaining estimated time 4111.049377236673
# None
#
#  545 of 1603 remaining estimated time 4108.508346269419
# None
#
#  546 of 1603 remaining estimated time 4105.903319665675
# None
#
#  547 of 1603 remaining estimated time 4103.344830130139
# None
#
#  548 of 1603 remaining estimated time 4098.785289523814
# None
#
#  549 of 1603 remaining estimated time 4094.2376626110076
# None
#
#  550 of 1603 remaining estimated time 4091.662985344764
# None
#
#  551 of 1603 remaining estimated time 4085.239253439765
# None
#
#  552 of 1603 remaining estimated time 4082.6197428535165
# None
#
#  553 of 1603 remaining estimated time 4078.164348425848
# None
#
#  554 of 1603 remaining estimated time 4075.510699791951
# None
#
#  555 of 1603 remaining estimated time 4076.5996613022235
# None
#
#  556 of 1603 remaining estimated time 4073.420964165693
# None
#
#  557 of 1603 remaining estimated time 4068.902675932881
# None
#
#  558 of 1603 remaining estimated time 4066.433761160361
# None
#
#  559 of 1603 remaining estimated time 4060.391774562427
# P3T;
#
#  560 of 1603 remaining estimated time 4057.7808938532166
# None
#
#  561 of 1603 remaining estimated time 4053.3298309731736
# None
#
#  562 of 1603 remaining estimated time 4048.9828258860807
# None
#
#  563 of 1603 remaining estimated time 4048.1702724078023
# PEDOT:PSS
#
#  564 of 1603 remaining estimated time 4043.8040933035113
# PEDOT:PSS
#
#  565 of 1603 remaining estimated time 4037.4458379079933
# PEDOT:PSS
#
#  566 of 1603 remaining estimated time 4037.0357130637667
# PEDOT:PSS
#
#  567 of 1603 remaining estimated time 4032.5086266255717
# PEDOT:PSS
#
#  568 of 1603 remaining estimated time 4029.7565284533744
# None
#
#  569 of 1603 remaining estimated time 4027.051460893531
# PEDOT:PSS
#
#  570 of 1603 remaining estimated time 4026.144271615508
# None
#
#  571 of 1603 remaining estimated time 4021.612173547278
# PEDOT:PSS
#
#  572 of 1603 remaining estimated time 4019.0319761634914
# None
#
#  573 of 1603 remaining estimated time 4016.2984403126748
# None
#
#  574 of 1603 remaining estimated time 4011.809497424001
# None
#
#  575 of 1603 remaining estimated time 4009.050943263703
# None
#
#  576 of 1603 remaining estimated time 4008.213458987208
# None
#
#  577 of 1603 remaining estimated time 4005.462716508489
# None
#
#  578 of 1603 remaining estimated time 3999.2335319107265
# None
#
#  579 of 1603 remaining estimated time 3994.6508911132814
# P3MEET; P3MEEMT; P3MEEET
#
#  580 of 1603 remaining estimated time 3995.5967331363495
# None
#
#  581 of 1603 remaining estimated time 3988.422655838052
# PEDOT; PSS
#
#  582 of 1603 remaining estimated time 3983.900129891178
# None
#
#  583 of 1603 remaining estimated time 3979.330456485487
# PEDOT:PSS
#
#  584 of 1603 remaining estimated time 3974.77265139319
# None
#
#  585 of 1603 remaining estimated time 3969.3580222146093
# None
#
#  586 of 1603 remaining estimated time 3966.637728703692
# None
#
#  587 of 1603 remaining estimated time 3962.105522690987
# PVA-co-PE; PPy
#
#  588 of 1603 remaining estimated time 3961.088283980844
# None
#
#  589 of 1603 remaining estimated time 3954.782950209763
# None
#
#  590 of 1603 remaining estimated time 3953.69803895563
# PEDOT:PSS
#
#  591 of 1603 remaining estimated time 3949.152324423597
# None
#
#  592 of 1603 remaining estimated time 3944.6661348471553
# PEDOT:PSS
#
#  593 of 1603 remaining estimated time 3940.201991162316
# None
#
#  594 of 1603 remaining estimated time 3935.665421226646
# None
#
#  595 of 1603 remaining estimated time 3931.090572024352
# PEDOT:PSS
#
#  596 of 1603 remaining estimated time 3926.70469670719
# None
#
#  597 of 1603 remaining estimated time 3927.8113097682044
# None
#
#  598 of 1603 remaining estimated time 3930.051222979923
# None
#
#  599 of 1603 remaining estimated time 3927.230787407557
# None
#
#  600 of 1603 remaining estimated time 3924.413593460835
# None
#
#  601 of 1603 remaining estimated time 3919.982715330251
# None
#
#  602 of 1603 remaining estimated time 3915.620318980557
# PEDOT:PSS
#
#  603 of 1603 remaining estimated time 3909.4716022346192
# None
#
#  604 of 1603 remaining estimated time 3906.7091159820557
# None
#
#  605 of 1603 remaining estimated time 3903.8128100881486
# None
#
#  606 of 1603 remaining estimated time 3897.6535473753634
# None
#
#  607 of 1603 remaining estimated time 3896.4987826880656
# None
#
#  608 of 1603 remaining estimated time 3893.6108073538353
# PMEBT; PMEET
#
#  609 of 1603 remaining estimated time 3892.381020660088
# None
#
#  610 of 1603 remaining estimated time 3889.626130741669
# None
#
#  611 of 1603 remaining estimated time 3888.691169452044
# None
#
#  612 of 1603 remaining estimated time 3882.4963371862596
# None
#
#  613 of 1603 remaining estimated time 3876.4620213283392
# None
#
#  614 of 1603 remaining estimated time 3871.2652971035095
# None
#
#  615 of 1603 remaining estimated time 3866.811929857576
# None
#
#  616 of 1603 remaining estimated time 3865.5703171207606
# None
#
#  617 of 1603 remaining estimated time 3861.1786993383207
# None
#
#  618 of 1603 remaining estimated time 3858.262641478047
# None
#
#  619 of 1603 remaining estimated time 3856.9368897038125
# None
#
#  620 of 1603 remaining estimated time 3852.4949380994417
# None
#
#  621 of 1603 remaining estimated time 3850.403525024365
# None
#
#  622 of 1603 remaining estimated time 3849.197928063559
# None
#
#  623 of 1603 remaining estimated time 3847.8368095174815
# None
#
#  624 of 1603 remaining estimated time 3846.4692919567105
# None
#
#  625 of 1603 remaining estimated time 3840.397912207503
# None
#
#  626 of 1603 remaining estimated time 3834.2847676528127
# None
#
#  627 of 1603 remaining estimated time 3831.485287733139
# None
#
#  628 of 1603 remaining estimated time 3830.077938804187
# PEDOT:PSS
#
#  629 of 1603 remaining estimated time 3824.100304687591
# None
#
#  630 of 1603 remaining estimated time 3822.9403946331677
# BBL
#
#  631 of 1603 remaining estimated time 3818.542507020733
# None
#
#  632 of 1603 remaining estimated time 3817.0549554591307
# None
#
#  633 of 1603 remaining estimated time 3814.1167033696397
# CPE-K
#
#  634 of 1603 remaining estimated time 3812.6913068977865
# None
#
#  635 of 1603 remaining estimated time 3805.0893934957635
# PEDOT
#
#  636 of 1603 remaining estimated time 3802.1313439429837
# None
#
#  637 of 1603 remaining estimated time 3800.6922235055404
# None
#
#  638 of 1603 remaining estimated time 3797.7027609519932
# None
#
#  639 of 1603 remaining estimated time 3794.8042821794747
# None
#
#  640 of 1603 remaining estimated time 3790.2290788217565
# None
#
#  641 of 1603 remaining estimated time 3785.6716884140656
# None
#
#  642 of 1603 remaining estimated time 3782.639425790143
# PEDOT-TOS; PAA-HCl
#
#  643 of 1603 remaining estimated time 3778.187044037055
# None
#
#  644 of 1603 remaining estimated time 3773.678012539989
# None
#
#  645 of 1603 remaining estimated time 3770.6550221989396
# None
#
#  646 of 1603 remaining estimated time 3769.165406446
# PBBTL; BBL
#
#  647 of 1603 remaining estimated time 3766.1443348696203
# PEDOT:PSS; P(EDOTCOOH-co-EDOTS)
#
#  648 of 1603 remaining estimated time 3764.7035770350135
# None
#
#  649 of 1603 remaining estimated time 3760.1605532257377
# None
#
#  650 of 1603 remaining estimated time 3757.3732627075387
# None
#
#  651 of 1603 remaining estimated time 3754.375409012192
# PEDOT:PSS
#
#  652 of 1603 remaining estimated time 3749.84348581834
# PEDOT:PSS
#
#  653 of 1603 remaining estimated time 3747.275819854999
# None
#
#  654 of 1603 remaining estimated time 3742.7387813859314
# None
#
#  655 of 1603 remaining estimated time 3739.8781431041116
# PEDOT:PSS
#
#  656 of 1603 remaining estimated time 3735.2715418400467
# None
#
#  657 of 1603 remaining estimated time 3732.147733369497
# None
#
#  658 of 1603 remaining estimated time 3724.7097506020245
# None
#
#  659 of 1603 remaining estimated time 3720.1444801735156
# PEDOT/PSS
#
#  660 of 1603 remaining estimated time 3718.763286958484
# None
#
#  661 of 1603 remaining estimated time 3713.5269929793667
# None
#
#  662 of 1603 remaining estimated time 3711.9370722558524
# PEDOT:PSS
#
#  663 of 1603 remaining estimated time 3706.0110043330365
# None
#
#  664 of 1603 remaining estimated time 3704.3175192101558
# None
#
#  665 of 1603 remaining estimated time 3701.238556417259
# None
#
#  666 of 1603 remaining estimated time 3699.5933922298664
# None
#
#  667 of 1603 remaining estimated time 3696.7008786087263
# None
#
#  668 of 1603 remaining estimated time 3693.847836065364
# None
#
#  669 of 1603 remaining estimated time 3689.3145222521543
# P(N,N'-BGNaD-co-BT-co-N,N'-ODNaD)
#
#  670 of 1603 remaining estimated time 3687.837435184044
# None
#
#  671 of 1603 remaining estimated time 3684.8043939088075
# None
#
#  672 of 1603 remaining estimated time 3681.6684042628062
# None
#
#  673 of 1603 remaining estimated time 3678.485176149391
# MIEC
#
#  674 of 1603 remaining estimated time 3675.370049372779
# None
#
#  675 of 1603 remaining estimated time 3668.0589882438703
# None
#
#  676 of 1603 remaining estimated time 3666.3566246575056
# None
#
#  677 of 1603 remaining estimated time 3662.531702949586
# PPP
#
#  678 of 1603 remaining estimated time 3658.016213840518
# PEDOT-PSS
#
#  679 of 1603 remaining estimated time 3656.219266012136
# PEDOT; PAH
#
#  680 of 1603 remaining estimated time 3655.975180925952
# None
#
#  681 of 1603 remaining estimated time 3651.7508838204694
# PEDOT:PSS
#
#  682 of 1603 remaining estimated time 3647.2276623538787
# None
#
#  683 of 1603 remaining estimated time 3644.0349119030243
# None
#
#  684 of 1603 remaining estimated time 3639.5477532682626
# None
#
#  685 of 1603 remaining estimated time 3635.0514730691216
# None
#
#  686 of 1603 remaining estimated time 3630.50495844394
# None
#
#  687 of 1603 remaining estimated time 3625.9659809373147
# None
#
#  688 of 1603 remaining estimated time 3624.0906867216218
# PEDOT:PSS; PEDOT:PolyDADMA Cl; PEDOT:PolyDADMA FSI; PEDOT:PolyDADMA TFSI; PEDOT:PolyDADMA CF3SO3; PEDOT:PolyDADMA Tos
#
#  689 of 1603 remaining estimated time 3621.1991064251333
# None
#
#  690 of 1603 remaining estimated time 3617.979032150053
# PEDOT:PSS; PEDOT
#
#  691 of 1603 remaining estimated time 3613.4043267145325
# None
#
#  692 of 1603 remaining estimated time 3609.2376983268955
# None
#
#  693 of 1603 remaining estimated time 3604.7042563119608
# None
#
#  694 of 1603 remaining estimated time 3601.5531239094494
# PEDOT:PSS
#
#  695 of 1603 remaining estimated time 3595.959995506824
# None
#
#  696 of 1603 remaining estimated time 3591.527306981203
# None
#
#  697 of 1603 remaining estimated time 3589.6410629885927
# None
#
#  698 of 1603 remaining estimated time 3586.4019860218523
# None
#
#  699 of 1603 remaining estimated time 3584.6654404394967
# None
#
#  700 of 1603 remaining estimated time 3580.1201948833873
# P3HT; rr-P3HT
#
#  701 of 1603 remaining estimated time 3579.6701832530844
# PEDOT:PSS
#
#  702 of 1603 remaining estimated time 3573.8752653405472
# None
#
#  703 of 1603 remaining estimated time 3571.944063834169
# PEDOT; PAMPS
#
#  704 of 1603 remaining estimated time 3568.7154050627496
# None
#
#  705 of 1603 remaining estimated time 3568.3815664407553
# None
#
#  706 of 1603 remaining estimated time 3564.12171884035
# None
#
#  707 of 1603 remaining estimated time 3561.141558544784
# PEDOT: PSS
#
#  708 of 1603 remaining estimated time 3556.710692734913
# None
#
#  709 of 1603 remaining estimated time 3554.710064661671
# PEDOT:PSS
#
#  710 of 1603 remaining estimated time 3551.5279783092637
# None
#
#  711 of 1603 remaining estimated time 3547.0045310165106
# None
#
#  712 of 1603 remaining estimated time 3542.5388470582175
# LSM
#
#  713 of 1603 remaining estimated time 3538.0050050243944
# None
#
#  714 of 1603 remaining estimated time 3534.6960120794656
# None
#
#  715 of 1603 remaining estimated time 3534.07266011318
# None
#
#  716 of 1603 remaining estimated time 3530.8543456451994
# PEDOT:PSS
#
#  717 of 1603 remaining estimated time 3527.5710337958963
# PEDOT:PSS
#
#  718 of 1603 remaining estimated time 3523.016467561974
# None
#
#  719 of 1603 remaining estimated time 3518.931484621101
# None
#
#  720 of 1603 remaining estimated time 3514.5028254618755
# None
#
#  721 of 1603 remaining estimated time 3509.9763270342446
# None
#
#  722 of 1603 remaining estimated time 3506.760461180042
# None
#
#  723 of 1603 remaining estimated time 3501.013082746643
# None
#
#  724 of 1603 remaining estimated time 3498.9446784121415
# None
#
#  725 of 1603 remaining estimated time 3495.6738354227105
# None
#
#  726 of 1603 remaining estimated time 3493.6288579412144
# Ag1.92Te
#
#  727 of 1603 remaining estimated time 3491.51094025832
# P(NDIEG7-FSVS); P(NDIOD-FSVS); Pg4NDI-T2; Pg4NDI-gT2
#
#  728 of 1603 remaining estimated time 3487.174584746197
# None
#
#  729 of 1603 remaining estimated time 3485.3257381981366
# None
#
#  730 of 1603 remaining estimated time 3480.802034878372
# None
#
#  731 of 1603 remaining estimated time 3476.269061620118
# None
#
#  732 of 1603 remaining estimated time 3472.937559827776
# EOECT
#
#  733 of 1603 remaining estimated time 3468.4206107689183
# BBL;
#
#  734 of 1603 remaining estimated time 3464.0934357802075
# None
#
#  735 of 1603 remaining estimated time 3460.747875419648
# None
#
#  736 of 1603 remaining estimated time 3456.2682510674244
# None
#
#  737 of 1603 remaining estimated time 3451.7389704399316
# None
#
#  738 of 1603 remaining estimated time 3448.3903366367613
# None
#
#  739 of 1603 remaining estimated time 3442.7005267478326
# PEDOT:PSS
#
#  740 of 1603 remaining estimated time 3439.563796306911
# PEDOT:PSS
#
#  741 of 1603 remaining estimated time 3435.1707380055736
# None
#
#  742 of 1603 remaining estimated time 3431.8005140360397
# PEDOT:PSS
#
#  743 of 1603 remaining estimated time 3427.319784017019
# None
#
#  744 of 1603 remaining estimated time 3423.9613874457827
# None
#
#  745 of 1603 remaining estimated time 3420.6242854166926
# PEDOT:PSS
#
#  746 of 1603 remaining estimated time 3416.1578536004904
# PEDOT:PSS
#
# ...
# None
#
#  1361 of 1603 remaining estimated time 997.5915150775434
# PEDOT:PSS
#
#  1362 of 1603 remaining estimated time 993.3794704734273
# P3HT
#
#  1363 of 1603 remaining estimated time 989.1535215993082
# PEDOT:PSS; PEDOT:PF6
#
#  1364 of 1603 remaining estimated time 985.1390307363573
# None
#
#  1365 of 1603 remaining estimated time 981.2622507690161
# P3MEEMT; P3HT
#
#  1366 of 1603 remaining estimated time 977.3852955860733
# PEDOT:PSS
#
#  1367 of 1603 remaining estimated time 972.8141659714325
# None
#
#  1368 of 1603 remaining estimated time 968.7620761544274
# None
#
#  1369 of 1603 remaining estimated time 964.5356543540955
# PEDOT:PSS
#
#  1370 of 1603 remaining estimated time 960.6529754171573
# PEDOT:PSS
#
#  1371 of 1603 remaining estimated time 956.6076556822997
# None
#
#  1372 of 1603 remaining estimated time 952.7292121564569
# None
#
#  1373 of 1603 remaining estimated time 948.6749536467083
# P3HT; PBTTT; DPPT-TT
#
#  1374 of 1603 remaining estimated time 944.6232218967785
# None
#
#  1375 of 1603 remaining estimated time 940.9018222648043
# P3HT
#
#  1376 of 1603 remaining estimated time 936.6911333221929
# None
#
#  1377 of 1603 remaining estimated time 932.6345142024002
# None
#
#  1378 of 1603 remaining estimated time 928.409055465369
# None
#
#  1379 of 1603 remaining estimated time 924.1835789003235
# PEDOT:PSS; PCPDTBT-SO3K
#
#  1380 of 1603 remaining estimated time 919.9667772290328
# Nafion
#
#  1381 of 1603 remaining estimated time 915.9066529184279
# None
#
#  1382 of 1603 remaining estimated time 911.8530814656295
# PEDOT:PSS
#
#  1383 of 1603 remaining estimated time 907.809777669824
# PEDOT:PSS
#
#  1384 of 1603 remaining estimated time 903.9104404294534
# None
#
#  1385 of 1603 remaining estimated time 899.6969688895116
# None
#
#  1386 of 1603 remaining estimated time 895.6459196939173
# None
#
#  1387 of 1603 remaining estimated time 891.7468588895001
# None
#
#  1388 of 1603 remaining estimated time 887.5284878000929
# None
#
#  1389 of 1603 remaining estimated time 883.778006056916
# PPy
#
#  1390 of 1603 remaining estimated time 879.3982909085681
# PEDOT
#
#  1391 of 1603 remaining estimated time 875.5393896986698
# OECT
#
#  1392 of 1603 remaining estimated time 871.6273014470132
# None
#
#  1393 of 1603 remaining estimated time 867.4103086425721
# None
#
#  1394 of 1603 remaining estimated time 862.8880741650913
# None
#
#  1395 of 1603 remaining estimated time 858.5192326898218
# None
#
#  1396 of 1603 remaining estimated time 854.6036673696364
# None
#
#  1397 of 1603 remaining estimated time 850.0926401369561
# PEDOT:PSS
#
#  1398 of 1603 remaining estimated time 846.0346272095686
# None
#
#  1399 of 1603 remaining estimated time 842.1264879390171
# None
#
#  1400 of 1603 remaining estimated time 838.0686332636608
# PEDOT:PSS
#
#  1401 of 1603 remaining estimated time 834.0132991118029
# PEDOT:PSS
#
#  1402 of 1603 remaining estimated time 830.0889827668113
# None
#
#  1403 of 1603 remaining estimated time 826.0161739808542
# MOECTs
#
#  1404 of 1603 remaining estimated time 821.9497498512268
# None
#
#  1405 of 1603 remaining estimated time 817.8859799152418
# None
#
#  1406 of 1603 remaining estimated time 813.8151376155902
# None
#
#  1407 of 1603 remaining estimated time 810.0218457119032
# None
#
#  1408 of 1603 remaining estimated time 805.9441626545721
# PEDOT:PSS
#
#  1409 of 1603 remaining estimated time 801.941475582461
# PEDOT:PSS
#
#  1410 of 1603 remaining estimated time 798.0007801537475
# PEDOT:PSS
#
#  1411 of 1603 remaining estimated time 794.069089689606
# None
#
#  1412 of 1603 remaining estimated time 789.9888372517441
# None
#
#  1413 of 1603 remaining estimated time 785.7696491437721
# None
#
#  1414 of 1603 remaining estimated time 781.7534166019291
# PEDOT:PSS; PEDOT
#
#  1415 of 1603 remaining estimated time 777.6776968900766
# PEDOT:PSS
#
#  1416 of 1603 remaining estimated time 773.5995414273875
# None
#
#  1417 of 1603 remaining estimated time 769.5170472720782
# None
#
#  1418 of 1603 remaining estimated time 765.1675943390765
# None
#
#  1419 of 1603 remaining estimated time 761.091486044333
# None
#
#  1420 of 1603 remaining estimated time 757.7881213591857
# PEDOT:PSS; PEDOT
#
#  1421 of 1603 remaining estimated time 753.5712087687562
# PEDOT:PSS
#
#  1422 of 1603 remaining estimated time 749.2958732038338
# PNDI2OD-2Tz; PNDIODTEG-2Tz; PNDI2TEG-2Tz
#
#  1423 of 1603 remaining estimated time 745.2180892563937
# None
#
#  1424 of 1603 remaining estimated time 741.1289522552489
# p(g2T-T); Homo-gDPP
#
#  1425 of 1603 remaining estimated time 737.0440923505545
# None
#
#  1426 of 1603 remaining estimated time 733.0190725174498
# None
#
#  1427 of 1603 remaining estimated time 728.9358676007481
# None
#
#  1428 of 1603 remaining estimated time 724.594283679551
# None
#
#  1429 of 1603 remaining estimated time 721.0006919950872
# None
#
#  1430 of 1603 remaining estimated time 716.7823686464777
# PEDOT:PSS;p(g2T-TT)
#
#  1431 of 1603 remaining estimated time 712.5695871307863
# gNDI-FBT
#
#  1432 of 1603 remaining estimated time 708.6019878137886
# None
#
#  1433 of 1603 remaining estimated time 704.3853821930693
# None
#
#  1434 of 1603 remaining estimated time 700.0520068138734
# PEDOT:PSS
#
#  1435 of 1603 remaining estimated time 695.8399025351224
# PEDOT-PSS
#
#  1436 of 1603 remaining estimated time 691.7479014701948
# Nafion;
#
#  1437 of 1603 remaining estimated time 687.5341261205818
# gAIID-2FT
#
#  1438 of 1603 remaining estimated time 683.3245824375776
# None
#
#  1439 of 1603 remaining estimated time 679.1133611440658
# None
#
#  1440 of 1603 remaining estimated time 675.1934394245757
# None
#
#  1441 of 1603 remaining estimated time 670.7577986244355
# None
#
#  1442 of 1603 remaining estimated time 666.5472736703962
# PEDOT:PSS
#
#  1443 of 1603 remaining estimated time 662.2292588093934
# None
#
#  1444 of 1603 remaining estimated time 658.1351202979632
# None
#
#  1445 of 1603 remaining estimated time 653.9385397071496
# None
#
#  1446 of 1603 remaining estimated time 649.6252319570566
# None
#
#  1447 of 1603 remaining estimated time 645.4274239658652
# PEDOT:PSS
#
#  1448 of 1603 remaining estimated time 641.451693214656
# PEDOT:PSS
#
#  1449 of 1603 remaining estimated time 637.4640527462136
# None
#
#  1450 of 1603 remaining estimated time 633.3661803924815
# None
#
#  1451 of 1603 remaining estimated time 629.478079816855
# None
#
#  1452 of 1603 remaining estimated time 625.1698459239968
# None
#
#  1453 of 1603 remaining estimated time 620.9697391176813
# None
#
#  1454 of 1603 remaining estimated time 616.7676439475358
# BBL; BAL; Cl4-BAL
#
#  1455 of 1603 remaining estimated time 612.6034981451193
# n-PBDF
#
#  1456 of 1603 remaining estimated time 608.6098701443341
# None
#
#  1457 of 1603 remaining estimated time 604.4065605119096
# None
#
#  1458 of 1603 remaining estimated time 600.2046050005697
# None
#
#  1459 of 1603 remaining estimated time 596.0019038082802
# None
#
#  1460 of 1603 remaining estimated time 591.8034424685518
# None
#
#  1461 of 1603 remaining estimated time 587.6033474909785
# None
#
#  1462 of 1603 remaining estimated time 583.4060843432512
# None
#
#  1463 of 1603 remaining estimated time 579.2127188111915
# P4E4; PEO
#
#  1464 of 1603 remaining estimated time 575.0187787495375
# PPODT; None of the mentioned polymers are OMIEC-type.
#
#  1465 of 1603 remaining estimated time 571.1133037586004
# PEDOT:PSS
#
#  1466 of 1603 remaining estimated time 567.2010900447705
# PEDOT:PSS
#
#  1467 of 1603 remaining estimated time 562.9089957180075
# PGDGDA
#
#  1468 of 1603 remaining estimated time 558.9940144757659
# None
#
#  1469 of 1603 remaining estimated time 554.7066543361768
# None
#
#  1470 of 1603 remaining estimated time 550.5606359441939
# None
#
#  1471 of 1603 remaining estimated time 546.3674515038729
# OECT
#
#  1472 of 1603 remaining estimated time 542.175695873974
# None
#
#  1473 of 1603 remaining estimated time 537.9833254982368
# None
#
#  1474 of 1603 remaining estimated time 533.7087662048663
# Nafion; Chitosan
#
#  1475 of 1603 remaining estimated time 529.5193576140779
# None
#
#  1476 of 1603 remaining estimated time 525.4601325961328
# None
#
#  1477 of 1603 remaining estimated time 521.1866676846118
# None
#
#  1478 of 1603 remaining estimated time 516.9994754513991
# P3HT; N2200
#
#  1479 of 1603 remaining estimated time 512.8974420463717
# PEDOT:PSS; PDDA
#
#  1480 of 1603 remaining estimated time 508.7140717714079
# PEDOT:PSS
#
#  1481 of 1603 remaining estimated time 504.5295637712466
# None
#
#  1482 of 1603 remaining estimated time 500.42333541009685
# None
#
#  1483 of 1603 remaining estimated time 496.23857726305323
# None
#
#  1484 of 1603 remaining estimated time 492.05345041085576
# PEDOT:PSS
#
#  1485 of 1603 remaining estimated time 487.95929741731084
# None
#
#  1486 of 1603 remaining estimated time 483.77890218995765
# PEDOT:PSS
#
#  1487 of 1603 remaining estimated time 479.59852307393993
# None
#
#  1488 of 1603 remaining estimated time 475.4957648353179
# None
#
#  1489 of 1603 remaining estimated time 471.2397594643919
# PEDOT:PSS; P3HT
#
#  1490 of 1603 remaining estimated time 467.1413045968888
# None
#
#  1491 of 1603 remaining estimated time 463.03812362169765
# None
#
#  1492 of 1603 remaining estimated time 458.8623405015477
# None
#
#  1493 of 1603 remaining estimated time 454.76016374476944
# PEDOT:PSS
#
#  1494 of 1603 remaining estimated time 450.5080361562429
# PEDOT:PSS
#
#  1495 of 1603 remaining estimated time 446.70020595655086
# None
#
#  1496 of 1603 remaining estimated time 442.523165039325
# None
#
#  1497 of 1603 remaining estimated time 438.4884590494617
# None
#
#  1498 of 1603 remaining estimated time 434.30925919979387
# PEDOT:PSS
#
#  1499 of 1603 remaining estimated time 430.13902811559046
# PEDOT:PSS; PANI
#
#  1500 of 1603 remaining estimated time 426.0324033520207
# None
#
#  1501 of 1603 remaining estimated time 421.92175275222286
# PEDOT:PSS
#
#  1502 of 1603 remaining estimated time 417.7490894481966
# None
#
#  1503 of 1603 remaining estimated time 413.63960601230883
# None
#
#  1504 of 1603 remaining estimated time 409.56366644444256
# PEDOT:PSS
#
#  1505 of 1603 remaining estimated time 405.3881816677205
# PEDOT-Phos; PEDOT
#
#  1506 of 1603 remaining estimated time 401.3101734319268
# None
#
#  1507 of 1603 remaining estimated time 397.1957149707987
# None
#
#  1508 of 1603 remaining estimated time 393.0210979676863
# PEDOT; EDOT; EDOTOA
#
#  1509 of 1603 remaining estimated time 388.91245280733176
# None
#
#  1510 of 1603 remaining estimated time 384.86108204531087
# None
#
#  1511 of 1603 remaining estimated time 380.68561126189263
# PEDOT:PSS
#
#  1512 of 1603 remaining estimated time 376.57231473970006
# None
#
#  1513 of 1603 remaining estimated time 372.4575513609177
# PEDOT-PC
#
#  1514 of 1603 remaining estimated time 368.34390613883244
# None
#
#  1515 of 1603 remaining estimated time 364.2317389146005
# PEDOT:PSS
#
#  1516 of 1603 remaining estimated time 360.0625217284666
# PEDOT:Tos
#
#  1517 of 1603 remaining estimated time 355.9460416311332
# PEDOT:PSS;
#
#  1518 of 1603 remaining estimated time 351.8318121475637
# None
#
#  1519 of 1603 remaining estimated time 347.71419956746854
# PEDOT:PSS
#
#  1520 of 1603 remaining estimated time 343.59876223334663
# None
#
#  1521 of 1603 remaining estimated time 339.5356579043079
# Nafion
#
#  1522 of 1603 remaining estimated time 335.3626567587912
# PEDOT:PSS
#
#  1523 of 1603 remaining estimated time 331.28637872030106
# PEDOT:PSS
#
#  1524 of 1603 remaining estimated time 327.11495000714166
# PEDOT-PAH; PEDOT-polyamine
#
#  1525 of 1603 remaining estimated time 323.02370867972917
# Nafion;
#
#  1526 of 1603 remaining estimated time 318.90265395802146
# PEDOT:PSS
#
#  1527 of 1603 remaining estimated time 314.7828142193599
# P3HT
#
#  1528 of 1603 remaining estimated time 310.70979688976854
# pDDA; PHT
#
#  1529 of 1603 remaining estimated time 306.5405594754063
# None
#
#  1530 of 1603 remaining estimated time 302.4642245151263
# None
#
#  1531 of 1603 remaining estimated time 298.3421995994628
# Pg2T-T; P3HT
#
#  1532 of 1603 remaining estimated time 294.2689004645811
# PEDOT:PSS
#
#  1533 of 1603 remaining estimated time 290.1904763982691
# PEDOT
#
#  1534 of 1603 remaining estimated time 286.06221497998564
# None
#
#  1535 of 1603 remaining estimated time 281.9333860861758
# None
#
#  1536 of 1603 remaining estimated time 277.80403234203214
# PEDOT:PSS
#
#  1537 of 1603 remaining estimated time 273.74392437221786
# PEDOT:PSS
#
#  1538 of 1603 remaining estimated time 269.61267531189225
# P3MEEMT
#
#  1539 of 1603 remaining estimated time 265.5236168006798
# None
#
#  1540 of 1603 remaining estimated time 261.5983816627401
# OMIEC
#
#  1541 of 1603 remaining estimated time 257.38044479910656
# None
#
#  1542 of 1603 remaining estimated time 253.24302820763802
# BBL
#
#  1543 of 1603 remaining estimated time 249.18491752654157
# PEDOT:PSS; PVA
#
#  1544 of 1603 remaining estimated time 245.02470664561372
# None
#
#  1545 of 1603 remaining estimated time 240.8506366460166
# None
#
#  1546 of 1603 remaining estimated time 236.71207656595269
# None
#
#  1547 of 1603 remaining estimated time 232.6138265804419
# None
#
#  1548 of 1603 remaining estimated time 228.43728912269165
# None
#
#  1549 of 1603 remaining estimated time 224.2967189293523
# None
#
#  1550 of 1603 remaining estimated time 220.0890739497487
# None
#
#  1551 of 1603 remaining estimated time 215.9495970121364
# None
#
#  1552 of 1603 remaining estimated time 211.7626018234015
# NDIP
#
#  1553 of 1603 remaining estimated time 207.65522461446864
# PAA/PANI
#
#  1554 of 1603 remaining estimated time 203.4841242345583
# None
#
#  1555 of 1603 remaining estimated time 199.37435602957913
# PEDOT:PSS
#
#  1556 of 1603 remaining estimated time 195.2320214062068
# None
#
#  1557 of 1603 remaining estimated time 191.07606411194462
# EG/GOPS-PEDOT:PSS;crys-PEDOT:PSS;pg2T-TT
#
#  1558 of 1603 remaining estimated time 186.96495314987138
# None
#
#  1559 of 1603 remaining estimated time 182.82260094300295
# None
#
#  1560 of 1603 remaining estimated time 178.70794028185028
# PTMA
#
#  1561 of 1603 remaining estimated time 174.5639378591017
# None
#
#  1562 of 1603 remaining estimated time 170.40549633690586
# PT-COOH; PT-OH
#
#  1563 of 1603 remaining estimated time 166.23325406437945
# None
#
#  1564 of 1603 remaining estimated time 162.08681717513088
# None
#
#  1565 of 1603 remaining estimated time 157.94055016835532
# None
#
#  1566 of 1603 remaining estimated time 153.74545039427682
# None
#
#  1567 of 1603 remaining estimated time 149.60144591878873
# PEDOT:PSS
#
#  1568 of 1603 remaining estimated time 145.3891958804401
# None
#
#  1569 of 1603 remaining estimated time 141.24441734514417
# None
#
#  1570 of 1603 remaining estimated time 137.09945677451313
# None
#
#  1571 of 1603 remaining estimated time 132.99365777459764
# DPPDTT; P3HT; Pg2T-T
#
#  1572 of 1603 remaining estimated time 128.80667386688552
# None
#
#  1573 of 1603 remaining estimated time 124.89250278684962
# None
#
#  1574 of 1603 remaining estimated time 120.85697845443848
# None
#
#  1575 of 1603 remaining estimated time 116.66368485767829
# PEDOT:PSS
#
#  1576 of 1603 remaining estimated time 112.50359433560563
# None
#
#  1577 of 1603 remaining estimated time 108.32608904675386
# None
#
#  1578 of 1603 remaining estimated time 104.15758614754512
# None
#
#  1579 of 1603 remaining estimated time 99.9818081771271
# None
#
#  1580 of 1603 remaining estimated time 95.83815086468499
# None
#
#  1581 of 1603 remaining estimated time 91.65018988228327
# None
#
#  1582 of 1603 remaining estimated time 87.47630073884132
# None
#
#  1583 of 1603 remaining estimated time 83.3153097226162
# None
#
#  1584 of 1603 remaining estimated time 79.15389815339532
# None
#
#  1585 of 1603 remaining estimated time 74.98055282426813
# None
#
#  1586 of 1603 remaining estimated time 70.81864933135304
# OECT
#
#  1587 of 1603 remaining estimated time 66.6268173285035
# None
#
#  1588 of 1603 remaining estimated time 62.46593392818059
# None
#
#  1589 of 1603 remaining estimated time 58.2961151602883
# None
#
#  1590 of 1603 remaining estimated time 54.1350802099982
# None
#
#  1591 of 1603 remaining estimated time 49.98150365136975
# None
#
#  1592 of 1603 remaining estimated time 45.81904638404751
# None
#
#  1593 of 1603 remaining estimated time 41.659195219707605
# PAA;
#
#  1594 of 1603 remaining estimated time 37.48679504768228
# None
#
#  1595 of 1603 remaining estimated time 33.313705183808366
# None
#
#  1596 of 1603 remaining estimated time 29.160364549907953
# None
#
#  1597 of 1603 remaining estimated time 25.00747051197238
# None
#
#  1598 of 1603 remaining estimated time 20.834489398035426
# None
#
#  1599 of 1603 remaining estimated time 16.676119389533998
# None
#
#  1600 of 1603 remaining estimated time 12.507926548815458
# Omiecinski
#
#  1601 of 1603 remaining estimated time 8.33972856167997
# None
#
#  1602 of 1603 remaining estimated time 4.171346752775957
# None

# %%
# DataFrame
df_with_responses = pd.DataFrame(responses_list)

# salvar para .csv
df_with_responses.to_excel('../../dataframes/llama3-70B-OMIEC160824_0.3_temp_RESPONSES.xlsx', index=False)

# %% [markdown]
# #### Playground

# %%
df_with_responses
# Out:
#      index                                           response
# 0        0                                              PEDOT
# 1        1                                               None
# 2        2  PEDOT:PolyDADMA; PEDOT:PolyDADMA FSI; PEDOT:Po...
# 3        3      conducting/semiconducting conjugated polymers
# 4        4                                          PEDOT:PSS
# ..     ...                                                ...
# 870    870                                               None
# 871    871                                               None
# 872    872                                               None
# 873    873                                               None
# 874    874                                               None
#
# [875 rows x 2 columns]

# %%
result = pd.concat([df_with_responses, df], axis=1)
result.drop('index', axis=1, inplace=True)
result = result[result['response'] != 'None']
result = result.reset_index(drop=True)

# %%
result.to_excel('1_OMIEC_RESPONSES_output.xlsx', index=False)

# %%
polímeros = []
for response in result['response']:
    polímeros = polímeros + response.split(';')

# %%
polímeros_processado = [s.strip() for s in polímeros]

# %%
serie_polímeros = pd.Series(polímeros_processado)
polímeros_filtrados = serie_polímeros[~serie_polímeros.str.contains(r'OMIEC.*', regex=True)]
polímeros_filtrados = polímeros_filtrados[polímeros_filtrados != '']
polímeros_filtrados = polímeros_filtrados[~polímeros_filtrados.str.contains(r'(?i)\bnone\b', regex=True)]
polímeros_filtrados = polímeros_filtrados[~polímeros_filtrados.str.contains('conduct')]
polímeros_filtrados = polímeros_filtrados[~polímeros_filtrados.str.contains('conjug')]
polímeros_filtrados = polímeros_filtrados[~polímeros_filtrados.str.contains('cellul')]
polímeros_filtrados = polímeros_filtrados[~polímeros_filtrados.str.contains(r'(?i)\bpolymer\b', regex=True)]
polímeros_filtrados = polímeros_filtrados[~polímeros_filtrados.str.contains(r'(?i)\bmixed\b', regex=True)]

# %%
replacements = {
    r'.*\((PEDOT:PSS)\)': r'\1',
    r'.*\((PEDOT)\)': r'\1',
    r'.*\((PEDOT-P)\)': r'\1',
    r'.*\((PEDOT-T)\)': r'\1',
    r'poly\(3,4-ethylenedioxythiophene\)': 'PEDOT',
    r'.*\((P3HT)\)': r'\1',
    r'.*\((PVDF)\)': r'\1',
    r'PEDOT:polystyrenesulfonate': 'PEDOT:PSS',
    r'PEDOT:polystyrene sulfonate': 'PEDOT:PSS',
    r'PEDOT\s*:\s*PSS': 'PEDOT:PSS',
    r'PEDOT\/PSS': 'PEDOT:PSS',
    r'PEDOT\/?poly\(4-styrenesulfonate\)': 'PEDOT:PSS',
    r'PEDOT\s*[-]\s*PSS': 'PEDOT:PSS'


}

# %%
for pattern, replacement in replacements.items():
    polímeros_filtrados = polímeros_filtrados.str.replace(pattern, replacement, regex=True, case=False)

# %%
len(serie_polímeros)
# Out:
# 683

# %%
len(polímeros_filtrados.unique())
# Out:
# 432

# %%
polímeros_filtrados.unique()
# Out:
# array(['PEDOT', 'PEDOT:PolyDADMA', 'PEDOT:PolyDADMA FSI',
#        'PEDOT:PolyDADMA TFSI', 'PEDOT:PSS', 'PSS', 'PEO-PEDOT',
#        'PANI/PSS', 'poly( vinylferrocene) (PVF)', 'P(3-MT-TTF)', 'PTFE',
#        'P(VDF-TrFE)', 'PBTTT', 'PVDF', 'P3HT', 'F4TCNQ', 'BPEEPTF', 'TTF',
#        'Bipolar polymers.', 'PEDOT-T', 'PEDOT-P',
#        "Poly(3,3'-dialkylimidazolium triflate)",
#        'Poly(tetraphenylphosphonium tetracyanometate)',
#        'Poly(3-methylthiophene)', 'Poly(o-phenylenediamine)',
#        'Poly(3-phenyl-phenylene sulfide)', 'EDOTS', 'EDOTCOOH', 'PProDOT',
#        'Polymerized ionic liquid', 'PMDT-TTF', 'TEDFE', 'PT-CSA-O-PTH',
#        'PT-TSPT', 'HPTS-PDBT.', 'EG/GOPS-PEDOT:PSS', 'pg2T-TT',
#        'f-BTI2g-TVTF', 'f-BTI2g-TVTCl', 'Polyparaphenylene',
#        'Ni-3(HITP)(2)', 'PEDOT-Cl', '[C(2)mpyr][FSI]', 'poly-FADS',
#        'gNR-Bu', 'PPSS', 'PPTFSI', 'f-BTI2g-SVSCN', 'f-BSeI2g-SVSCN',
#        'PyQt', 'PBTTT-C8', 'OMEC-5', '(C16H33CH2CH2CO2)2Sn', 'DTPT',
#        'PTAA-DMB', 'OMEM', 'OMEC-3', 'OMEC-4', 'OMEC-1', 'NDI-T2', 'Mel',
#        'polythiophene', 'PAAM', 'PDA', 'PANI', 'CNT-COOH', 'PBTT', 'PTAA',
#        'PEGDA', 'YEG', 'PPV', 'PTCDA', 'PIP-ITIC', 'P1N', 'P(BTTE-2Cl)',
#        'P(TSE-TT)', 'P(FBTTh2)', 'P(OH-TT)', 'PFBT2', 'DPP-FBT', 'DPP-TT',
#        'DPP-TES', 'P(TP-MEI)', 'P(NDIP2-OD)', 'TTF-PT', 'TTF-Th', 'ThT',
#        'P(BTSE-8)', 'P(NDTI2-OD)', 'P(FBTSe-2)', 'P(BTBP)', 'P(FBTT)',
#        'P(FBTSe-3)', 'DFT-P', 'P(BD4)', 'P(TDC)', 'P(TPF)', 'P(A3)',
#        'P(TP-C)', 'P(V3)', 'P(F3)', 'P(La1)', 'P(C7)', 'P(C6)', 'P(C4)',
#        'P(NFPE)', 'P(VTPT)', 'P(TNT).', 'Polypyrrole', 'PPO-LiTFSI',
#        'PAA/PANI', 'PEDOT-cobalt(II) hexylridge',
#        'PEDOT-silver perchlorate', 'Poly(styrenesulfonate)',
#        'C(2)mpyrFSI', 'C(2)mpyrTFSI', 'nonactin', 'PEO/NH4ClO4',
#        'Polyaniline', '(PDMA)PbI4', '(BzA)2PbI4', 'PCEI', 'PNDI-EG',
#        'TTF-CA', 'hPDI[3]',
#        'Poly(3,4-ethylenedithiotetrafluorothiophene) (PEDT-TF)', 'p(N-T)',
#        'polystyrene', 'MEH-PPV', 'PEO', 'IDTBT', 'p(NDI-T2 P75)',
#        'Ru(bpy)(3)(PF6)(2)', 'PEDOT-b-PEG', 'P-3O', 'P-4O', 'P-5O',
#        'P-6O', 'ppy-[B]Im', 'F8T2', 'poly(thiophene)', 'P3MEEET',
#        'LiTFSI', 'TNR', 'bgTNR', 'PDPP-4EG', 'PEDOT:PSS.', 'BBL',
#        'PSS:PPy', 'NDIP', 'p(g2T-T)', 'Homo-gDPP', 'PEDOT:Tos', 'PSSNa',
#        'mLPPP', 'f-BTI2g-TVTCN', 'f-BTI2g-TVT',
#        'Polymeric Naphthalene Diimide', 'Poly(3-dodecylthiophene) (P3DT)',
#        'P3HT-IM', 'gNDI-Br-2', 'PEDOT:PSS/SPEEK', 'poly(dioxythiophene)',
#        'PSS/SPEEK', 'PPP-R10', 'P5TT', 'Spiro-OMeTAD',
#        'poly(ethylene glycol)', 'CPs', 'MCP', '[Ch][Lac]',
#        'Pittsburgh Doped PANI', 'PPy', 'PMDT-TT2N, PTAA-PTCDA, ECPs',
#        '2SgPDI', 'gPDI', 'Poly-ID films', 'PANI-PPy blends', 'BA', 'PEA',
#        '1 T', '2P', 'poly(vinyl alcohol)', 'P3HT-b-POEM', 'CNg4T2-CNT2',
#        'g4T2-T2', 'ionic arylenediimides', 'naphthalenediimides',
#        'viologens', 'organogels', 'MA', 'MAPbI3', 'MAPbBr3', 'MAPbCl3',
#        'MAPb(ClxBr1-x)3', 'MAPb(BrxI1-x)3', 'IMI1,2O1TFSI',
#        'IMI1,1O2O1TFSI', 'BuMeIMITFSI', 'random copolymer',
#        'hydrophobic side-chains', 'polar side-chains', 'PPP-OR11',
#        'P(NDIEG7-FSVS)', 'P(NDIOD-FSVS)', 'Pg4NDI-T2', 'Pg4NDI-gT2',
#        'PNDI', '(BEDO-TTF)', '(BEDT-TTF)', 'PDMS',
#        'oEG-based regioregular polythiophene', 'PI-DTT', 'PVK-PF6',
#        'radical polymers', 'PE2gTT', 'PT2gT', 'PE2gT', 'PT2gTT', 'TIIP',
#        'DPP-based copolymers', 'd-gdiPDI', 't-gdiPDI', 'ZPS', 'PBDT-TG',
#        'PBDT-TG-TFSA', 'P3HT-TG', 'PQT-12-TG', 'Perylene bisimide',
#        'Li0.1MoS2(LiOEt)', 'Li0.1MoS2(NEt3)',
#        'Tetrathiafulvalene-p-chloranil',
#        'poly(p-phenylenevinylene) (PPV)', 'polyacetylene (PA)',
#        'P(NDI2OD-T2)', 'poly(S)-b-poly(VBBI+[X]-r-PEGMA)',
#        'Naphthalenediimide-based copolymer', 'PBFDO', 'DBTOP', 'POMEC',
#        'PCBM', 'C60-TEG', 'tetrathiafulvalene-p-chloranil', 'gDPP-TTT',
#        'gDPP-TTVTT', 'Chitosan:polyaniline (CPA)', 'PMeIm-Me-HT',
#        'HT-DNCH', 'POMeIm-Hex.', '(Me)(2)P-C(18)TCNQ', 'gIDT-BBT', 'PTEO',
#        'PPyPIL', 'PPEGMA', 'Pebax', 'POD', 'Ca-POD', 'formamidinium',
#        'guanidinium', 'P(NDIMTEG-T)', "poly(2,2'-bithiophene)",
#        'poly(phenylene)', 'PTBT-P', 'PTTBT-P',
#        'poly(3-hexylthiophene-2,5-diyl)', 'hexafluorophosphate',
#        'trifluoromethanesulfonylimide', '(OM)2MImPF(6)', 'PI-EBT',
#        'PQPC(6)', 'polythiophenes', 'triethylene glycol polymers', 'SEBS',
#        'Pg2T-S', 'Pg2T-SVS', 'Pg2T-T', 'p(ETE-S)',
#        'Polymerized 3,4-ethylenedioxythiophene-molybdenum disulfide',
#        'PEDOT-MoS2', 'PEDOT-PBA', 'МIP-PEDOT-PBA', 'OECT',
#        'Polythiophene', 'Spiro-MeOTAD', 'DPP-DTT', 'p(g(7)NC(4)N)',
#        'p(g(7)NC(10)N)', 'NDI derivative', 'PTHS(-)TMA(+)', 'CoPc',
#        'FePc', 'PBBT', 'PBBT-Me', 'OMeCGT', 'OME-TCDT', 'TDPP-gTVT',
#        'TDPP-gTBTT', 'F6TCNNQ', 'PEOE', 'PThi', 'PTMC', 'Ppy-CA',
#        'Cyano-OCF-EO', '(La,Sr)(Co,Fe)O3-delta', 'PIMTEOS', 'PTh', 'PVK',
#        'PCEO', 'PEGMEA', 'POMA', 'PDMI', 'PI', 'PThPy', 'Poly-thiophene',
#        'polyindole-based', 'Poly(N-vinylcarbazole)', 'OPBI', 'gNDI-V',
#        'gNDI-T', 'CPs.', 'Li[PF6]', '[CpTiCpCo](infinity)',
#        '[CpCrCpCo](infinity)', '[CpTiCpFe](infinity)',
#        '[CpCrCpFe](infinity)', '[CpFeCpCo](infinity)', 'BEDT-TTF',
#        'Pris-CPE-K', 'Re-CPE-Na', 'glycolated polythiophenes', 'Ppy:DBS',
#        'Thiophene-based trimer, DPA-modified', 'LS', 'DSLS', 'KL', 'PMDI',
#        'F16CuPc', 'CH3NH3PbBr3', 'CH3NH3PbI3', 'FAPbBr3', 'spiro-NDI-N',
#        '(ClMeTCNQ)', 'TTF-TCNQ', 'PIPAC', 'PIIs',
#        'Organic electrochemical transistors (OECTs)', 'M2P-TCNQF(4)',
#        'Paddlewheel-type diruthenium(II,II) complexes',
#        '7,7,8,8-tetracyano-p-quinodimethane (TCNQ)',
#        "N,N'-dicyanoquinodiimine (DCNQI)", 'PM6',
#        'PMDAS, PSS-DVB, PSS-Ac_MA, PvMMA, PANI', '[C6MIM][PF6]',
#        'Poly(3-(pyrrol-1-yl)thiophene)', 'Poly(3-(butylthiophene)',
#        'PVDF-HFP', 'polypyrrole', 'polyaniline',
#        'poly(2-acrylamido-2-methyl-1-propanesulfonic acid)', 'L2NO4',
#        'CPE-K', 'C18TCNQ', 'PTMBSA', 'C60', 'VOPc',
#        'vanadyltetralds(1,2,S-thiadiazole)porphyrazine', 'g2T2-gBT2',
#        'g2T2-gBT4', 'g2T2-gBT6', 'CsTFSI', 'PPEBBT-TT', 'PPEBBT', 'PBPBT',
#        'poly(ethylene oxide)', 'PTMA', 'PBI-NH3+',
#        'poly[Ni(CH(3)Osalen)]', 'NASICON', 'PProDOT-Ph', 'P3HT-PCBM',
#        'PTT-TNF-PF6', 'PFO-OEPIC-PF6', 'PEO-TFSI', 'PTEG',
#        'n-type polymeric gate electrode', 'CuHCF', 'CoHCF',
#        'Prussian Blue Analogue (PBA)', 'CH2(NH2)(2)PbI3',
#        '1-butyl-3-methylimidazolium hydrogen sulphate',
#        '1-octyl-3-methylimidazolium chloride',
#        '1-butyl-3-methylimidazolium bromide',
#        '1-hexyl-3-methylimidazolium bromide',
#        '1-octyl-3-methylimidazolium bromide',
#        '1-butyl-3-methylimidazolium chloride',
#        '1-octyl-3-methylimidazolium hydrogen sulphate', 'P(ProDOT)',
#        '2-CPHMN', 'p(g3T2)', 'P3TAA', 'PT-peptide', 'PT-perylene',
#        'PT-PBI-DY', 'PT-PBI-NH3+', 'P3TAA-ran-P3HT', 'MP-TTF',
#        'decyl-TCNQ', 'PDAC', 'RRa P3HT', 'F40PcCu', 'F16PcCu', 'F64PcCu',
#        'SBPBF4', 'pgBTTT', 'p(g2T-TT)', 'polyimide', 'PDT-50',
#        'Imidazole-type coatings', 'OLED-30', 'BEDO-TTF', 'TMTSF', 'Alg',
#        'naphthalene-1,4,5,8-tetracarboxylic-diimide-bithiophene', 'pNPV',
#        'PSe-DCNQIistine', 'PEG-2-DEME', 'PEG-3-DEME', 'poly(VTPA-co-AMS)',
#        'PTS-Na', 'PS-b-PMMA', 'PS-b-PLA', 'P3T'], dtype=object)

# %%
df_polímeros = pd.DataFrame(polímeros_filtrados, columns=['Polímeros'])

# %%
contagem = df_polímeros['Polímeros'].value_counts()

# %%
contagem.head(30)
# Out:
# Polímeros
# PEDOT:PSS               65
# PEDOT                   34
# P3HT                    18
# TTF-CA                   6
# PEO                      6
# polythiophene            4
# PANI                     4
# MEH-PPV                  4
# BBL                      3
# PSS                      3
# PTAA                     3
# Polyaniline              3
# PPV                      2
# Polypyrrole              2
# P3MEEET                  2
# LiTFSI                   2
# CH3NH3PbI3               2
# poly(ethylene oxide)     2
# Homo-gDPP                2
# NDI-T2                   2
# PSSNa                    2
# Spiro-OMeTAD             2
# PPy                      2
# g4T2-T2                  2
# (BEDT-TTF)               2
# PTEO                     2
# Polythiophene            2
# PTh                      2
# p(g2T-T)                 2
# P3T                      2
# Name: count, dtype: int64

# %%
np.unique(df_polímeros[df_polímeros['Polímeros'].str.contains(r'PEDOT', regex=True)].values.tolist())
# Out:
# array(['EG/GOPS-PEDOT:PSS', 'PEDOT', 'PEDOT-Cl', 'PEDOT-MoS2', 'PEDOT-P',
#        'PEDOT-PBA', 'PEDOT-T', 'PEDOT-b-PEG',
#        'PEDOT-cobalt(II) hexylridge', 'PEDOT-silver perchlorate',
#        'PEDOT:PSS', 'PEDOT:PSS.', 'PEDOT:PSS/SPEEK', 'PEDOT:PolyDADMA',
#        'PEDOT:PolyDADMA FSI', 'PEDOT:PolyDADMA TFSI', 'PEDOT:Tos',
#        'PEO-PEDOT', 'МIP-PEDOT-PBA'], dtype='<U27')

# %%
df_polímeros.to_excel('1_OMIEC_RESPONSES_output_preprocessed.xlsx', index=False)

# %%
df
